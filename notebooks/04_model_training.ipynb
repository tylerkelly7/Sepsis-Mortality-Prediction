# %% [markdown]
# # 04 Model Training & Baseline Evaluation
#
# This notebook loads all preprocessed datasets from 03 Feature Engineering,
# applies SMOTE to each variant’s training data, saves the balanced datasets,
# and performs model training.
#
# All train/test splits are fixed from 03 to prevent data leakage.
#
# This notebook focuses on training baseline classifiers for:
# - **Original structured features**
# - **Word2Vec (W2V) embeddings**
#
# Workflow:
# 1. Load processed datasets
# 2. Resampling with SMOTE
# 3. Define classifiers and parameter grids
# 4. Run mixed CV + hyperparameter search
# 5. Retrain best models on SMOTE-balanced sets
# 6. Save results (CSV + Markdown) for reporting

# %% [markdown]
# ## 0. Setup
# Import core modules

# %%
import psutil, os
print([p.info for p in psutil.process_iter(['pid','name']) if 'python' in p.info['name'].lower()])
# Out:
# [{'name': 'python.exe', 'pid': 8760}, {'name': 'python.exe', 'pid': 10172}, {'name': 'python.exe', 'pid': 25992}]

# %%
# --- One-time module reload cell (safe within Jupyter) ---

import importlib
import pandas as pd
import numpy as np
import os
from sklearn.metrics import roc_auc_score, make_scorer

# Core project imports
import src.models as models
import src.resampling as resampling
import src.utils as utils
import src.evaluation as evaluation

# Reload to ensure latest updates (e.g., _decision_or_proba, auc_scorer)
importlib.reload(models)
importlib.reload(resampling)
importlib.reload(utils)
importlib.reload(evaluation)

# Pull updated functions/classes into namespace
from src.models import (
    get_classifiers,
    get_param_distributions,
    get_n_iter_random_per_clf,
    repeated_cv_with_mixed_search,
    auc_scorer
)

from src.resampling import (
    resample_training_data,
    print_class_balance
)

from src.utils import resolve_path
from src.evaluation import export_summary

print("✅ All modules reloaded successfully (models, resampling, utils, evaluation).")
# Out:
# ✅ All modules reloaded successfully (models, resampling, utils, evaluation).

# %%
import pandas as pd
import numpy as np
import os
from sklearn.metrics import roc_auc_score, make_scorer

from src.models import (
    get_classifiers, 
    get_param_distributions,
    get_n_iter_random_per_clf,
    repeated_cv_with_mixed_search,
    auc_scorer
    
)

from src.resampling import resample_training_data, print_class_balance
from src.utils import resolve_path
from src.evaluation import export_summary

# %% [markdown]
# ## 1. Load Feature Datasets
# Load all variants (original, w2v_rad, w2v_dis, w2v_comb) produced in 03 Feature Engineering.
# Each variant includes four CSVs: `X_train`, `X_test`, `y_train`, `y_test`.

# %%
variants = ["original", "w2v_radiology", "w2v_discharge", "w2v_combined"]
datasets = {}

for variant in variants:
    X_train = pd.read_csv(resolve_path(f"data/processed/{variant}/data_{variant}_xtrain.csv"))
    X_test  = pd.read_csv(resolve_path(f"data/processed/{variant}/data_{variant}_xtest.csv"))
    y_train = pd.read_csv(resolve_path(f"data/processed/{variant}/data_{variant}_ytrain.csv")).squeeze()
    y_test  = pd.read_csv(resolve_path(f"data/processed/{variant}/data_{variant}_ytest.csv")).squeeze()

    datasets[variant] = {
        "X_train": X_train,
        "X_test": X_test,
        "y_train": y_train,
        "y_test": y_test
    }

    print(f"✅ Loaded {variant} dataset → Train: {X_train.shape}, Test: {X_test.shape}")
    print_class_balance(y_train, f"{variant} training set (before SMOTE)")
# Out:
# ✅ Loaded original dataset → Train: (4166, 43), Test: (1042, 43)
# original training set (before SMOTE) class balance: {0: 3204, 1: 962}
# ✅ Loaded w2v_radiology dataset → Train: (4166, 143), Test: (1042, 143)
# w2v_radiology training set (before SMOTE) class balance: {0: 3204, 1: 962}
# ✅ Loaded w2v_discharge dataset → Train: (4166, 143), Test: (1042, 143)
# w2v_discharge training set (before SMOTE) class balance: {0: 3204, 1: 962}
# ✅ Loaded w2v_combined dataset → Train: (4166, 143), Test: (1042, 143)
# w2v_combined training set (before SMOTE) class balance: {0: 3204, 1: 962}

# %% [markdown]
# ## 2. Apply SMOTE Per Variant
#
# Resample only the training set for each variant using SMOTE.
# This ensures the test set remains untouched for unbiased evaluation.

# %%
for variant, data in datasets.items():
    X_train_res, y_train_res = resample_training_data(
        data["X_train"], data["y_train"], method="smote"
    )
    datasets[variant]["X_train_res"] = X_train_res
    datasets[variant]["y_train_res"] = y_train_res
    print_class_balance(y_train_res, f"{variant} training set (after SMOTE)")
# Out:
# 🔁 Applying SMOTE to training data ...
# ✅ Resampled training set shape: (6408, 43)
#    Class balance after resampling: Counter({0: 3204, 1: 3204})
# original training set (after SMOTE) class balance: {0: 3204, 1: 3204}
# 🔁 Applying SMOTE to training data ...
# ✅ Resampled training set shape: (6408, 143)
#    Class balance after resampling: Counter({0: 3204, 1: 3204})
# w2v_radiology training set (after SMOTE) class balance: {0: 3204, 1: 3204}
# 🔁 Applying SMOTE to training data ...
# ✅ Resampled training set shape: (6408, 143)
#    Class balance after resampling: Counter({0: 3204, 1: 3204})
# w2v_discharge training set (after SMOTE) class balance: {0: 3204, 1: 3204}
# 🔁 Applying SMOTE to training data ...
# ✅ Resampled training set shape: (6408, 143)
#    Class balance after resampling: Counter({0: 3204, 1: 3204})
# w2v_combined training set (after SMOTE) class balance: {0: 3204, 1: 3204}

# %% [markdown]
# ## 3. Save SMOTE-Balanced Training Sets
#
# Each variant’s SMOTE-balanced training data are saved
# to `data/processed/{variant}` for external reuse and verification.
# Paths use `resolve_path()` for portability.

# %%
for variant, data in datasets.items():
    # Create variant-specific directory
    out_dir = resolve_path(f"data/processed/{variant}")
    os.makedirs(out_dir, exist_ok=True)

    # Save SMOTE-balanced training data and labels separately
    X_train_res = pd.DataFrame(data["X_train_res"])
    y_train_res = pd.Series(data["y_train_res"], name="target")

    # Save consistent with 03_feature_engineering style
    X_train_res.to_csv(os.path.join(out_dir, f"data_{variant}_xtrain_res.csv"), index=False)
    y_train_res.to_csv(os.path.join(out_dir, f"data_{variant}_ytrain_res.csv"), index=False)

    print(f"✅ Saved SMOTE-balanced training sets for {variant} under {out_dir}")
# Out:
# ✅ Saved SMOTE-balanced training sets for original under C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\data\processed\original
# ✅ Saved SMOTE-balanced training sets for w2v_radiology under C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\data\processed\w2v_radiology
# ✅ Saved SMOTE-balanced training sets for w2v_discharge under C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\data\processed\w2v_discharge
# ✅ Saved SMOTE-balanced training sets for w2v_combined under C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\data\processed\w2v_combined

# %% [markdown]
# ## 4. Define Classifiers & Hyperparameter Distributions
# Load from `src/models.py`:
# - `get_classifiers()` for base estimators
# - `get_param_distributions()` for Grid/Randomized search spaces

# %%
classifiers = get_classifiers()
param_spaces = get_param_distributions()
n_iter_random_per_clf = get_n_iter_random_per_clf()

print("✅ Classifiers and hyperparameter grids initialized.")
print("Available classifiers:", list(classifiers.keys()))
# Out:
# ✅ Classifiers and hyperparameter grids initialized.
# Available classifiers: ['LogisticRegression', 'DecisionTree', 'RandomForest', 'GradientBoosting', 'XGB', 'LGBM', 'CatBoost', 'SVC', 'MLP', 'NaiveBayes']

# %% [markdown]
# ## 5. Train on Structured Features (Original)
#
# The call to `repeated_cv_with_mixed_search()` runs both non-SMOTE and
# SMOTE-balanced training internally, logs results to MLflow, and saves
# artifacts to the appropriate `results/models/original/` folder.
#
# Run `repeated_cv_with_mixed_search`:
# - Hyperparameter search on non-SMOTE data
# - Retrain on SMOTE data with best params
# - Save models to `results/models/original/`
# - Evaluated on the holdout test set
# - Export summary to CSV + Markdown

# %%
X_train_orig = datasets["original"]["X_train"]
X_test_orig  = datasets["original"]["X_test"]
y_train_orig = datasets["original"]["y_train"]
y_test_orig  = datasets["original"]["y_test"]
X_train_smote_orig = datasets["original"]["X_train_res"]
y_train_smote_orig = datasets["original"]["y_train_res"]

results_orig, summary_orig = repeated_cv_with_mixed_search(
    X_train_orig, y_train_orig, X_test_orig, y_test_orig,
    classifiers=classifiers,
    param_spaces=param_spaces,
    X_train_smote=X_train_smote_orig,
    y_train_smote=y_train_smote_orig,
    n_splits=5,
    n_repeats=10,
    scoring=auc_scorer,
    n_iter_random=50,
    n_iter_random_per_clf=n_iter_random_per_clf,
    save_prefix="results/models/{mode}/",
    mode="original_baseline",
    log_mlflow=True
)

export_summary(summary_orig, save_prefix="reports/", mode="original_baseline")
print("✅ Finished model training for Original dataset.")
# Out:
# ✅ MLflow tracking initialized under unified experiment 'Thesis_ModelTraining'
# Tracking URI: file:///C:/Users/tyler/OneDrive%20-%20University%20of%20Pittsburgh/BIOST%202021%20Thesis/Masters-Thesis/mlflow_tracking (Experiment ID: 169692831354922862)
#
# 🔹 Running LogisticRegression...
# Fitting 50 folds for each of 44 candidates, totalling 2200 fits
#    Performing descriptive StratifiedKFold CV on original training set for LogisticRegression...
#    Descriptive CV AUC: 0.7039 ± 0.0140
# 💾 Saved LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LogisticRegression_model.pkl
# ✅ LogisticRegression done. Best params: {'clf__C': 0.01, 'clf__max_iter': 1000, 'clf__penalty': 'l2', 'clf__solver': 'liblinear'}
#    CV ROC-AUC: 0.706 ± 0.018
#    Holdout ROC-AUC: 0.723
# 💾 Saved non-SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LogisticRegression_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7162
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LogisticRegression...
#    Descriptive CV AUC (SMOTE): 0.7243 ± 0.0159
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LogisticRegression_smote_model.pkl
# 💾 Saved SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LogisticRegression_metrics_smote.json
# ⏱️  Runtime for LogisticRegression: 0.48 minutes
# 🏁 MLflow run for 'LogisticRegression' closed cleanly.
#
# 🔹 Running DecisionTree...
# Fitting 50 folds for each of 240 candidates, totalling 12000 fits
#    Performing descriptive StratifiedKFold CV on original training set for DecisionTree...
#    Descriptive CV AUC: 0.6620 ± 0.0165
# 💾 Saved DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_DecisionTree_model.pkl
# ✅ DecisionTree done. Best params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__min_samples_leaf': 10, 'clf__min_samples_split': 2}
#    CV ROC-AUC: 0.643 ± 0.023
#    Holdout ROC-AUC: 0.635
# 💾 Saved non-SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_DecisionTree_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6296
#    Performing descriptive StratifiedKFold CV on SMOTE training set for DecisionTree...
#    Descriptive CV AUC (SMOTE): 0.7271 ± 0.0135
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_DecisionTree_smote_model.pkl
# 💾 Saved SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_DecisionTree_metrics_smote.json
# ⏱️  Runtime for DecisionTree: 0.78 minutes
# 🏁 MLflow run for 'DecisionTree' closed cleanly.
#
# 🔹 Running RandomForest...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for RandomForest...
#    Descriptive CV AUC: 0.7197 ± 0.0206
# 💾 Saved RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_RandomForest_model.pkl
# ✅ RandomForest done. Best params: {'clf__bootstrap': True, 'clf__max_depth': 10, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 4, 'clf__min_samples_split': 7, 'clf__n_estimators': 935}
#    CV ROC-AUC: 0.720 ± 0.021
#    Holdout ROC-AUC: 0.726
# 💾 Saved non-SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_RandomForest_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7021
#    Performing descriptive StratifiedKFold CV on SMOTE training set for RandomForest...
#    Descriptive CV AUC (SMOTE): 0.8901 ± 0.0135
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_RandomForest_smote_model.pkl
# 💾 Saved SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_RandomForest_metrics_smote.json
# ⏱️  Runtime for RandomForest: 35.38 minutes
# 🏁 MLflow run for 'RandomForest' closed cleanly.
#
# 🔹 Running GradientBoosting...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for GradientBoosting...
#    Descriptive CV AUC: 0.7155 ± 0.0210
# 💾 Saved GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_GradientBoosting_model.pkl
# ✅ GradientBoosting done. Best params: {'clf__learning_rate': 0.013979488347959958, 'clf__max_depth': 3, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 2, 'clf__min_samples_split': 10, 'clf__n_estimators': 445, 'clf__subsample': 0.7293016342019151}
#    CV ROC-AUC: 0.717 ± 0.020
#    Holdout ROC-AUC: 0.727
# 💾 Saved non-SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_GradientBoosting_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7032
#    Performing descriptive StratifiedKFold CV on SMOTE training set for GradientBoosting...
#    Descriptive CV AUC (SMOTE): 0.8489 ± 0.0151
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_GradientBoosting_smote_model.pkl
# 💾 Saved SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_GradientBoosting_metrics_smote.json
# ⏱️  Runtime for GradientBoosting: 10.09 minutes
# 🏁 MLflow run for 'GradientBoosting' closed cleanly.
#
# 🔹 Running XGB...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:40] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Performing descriptive StratifiedKFold CV on original training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:40] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:41] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:41] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:42] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:42] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC: 0.7184 ± 0.0177
# 💾 Saved XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_XGB_model.pkl
# ✅ XGB done. Best params: {'clf__colsample_bytree': 0.9165996316800473, 'clf__gamma': 0.4692763545078751, 'clf__learning_rate': 0.010233629752304298, 'clf__max_depth': 6, 'clf__min_child_weight': 5, 'clf__n_estimators': 360, 'clf__subsample': 0.7912726728878613}
#    CV ROC-AUC: 0.717 ± 0.019
#    Holdout ROC-AUC: 0.729
# 💾 Saved non-SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_XGB_metrics_non_smote.json
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    SMOTE Holdout ROC-AUC: 0.7127
#    Performing descriptive StratifiedKFold CV on SMOTE training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:45] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:46] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:03:46] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC (SMOTE): 0.9106 ± 0.0083
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_XGB_smote_model.pkl
# 💾 Saved SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_XGB_metrics_smote.json
# ⏱️  Runtime for XGB: 3.47 minutes
# 🏁 MLflow run for 'XGB' closed cleanly.
#
# 🔹 Running LGBM...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for LGBM...
#    Descriptive CV AUC: 0.7069 ± 0.0161
# 💾 Saved LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LGBM_model.pkl
# ✅ LGBM done. Best params: {'clf__colsample_bytree': 0.7880464524154114, 'clf__learning_rate': 0.014223946814525337, 'clf__max_depth': 20, 'clf__min_child_samples': 90, 'clf__n_estimators': 591, 'clf__num_leaves': 193, 'clf__subsample': 0.9370526621593617}
#    CV ROC-AUC: 0.706 ± 0.017
#    Holdout ROC-AUC: 0.726
# 💾 Saved non-SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LGBM_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7099
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LGBM...
#    Descriptive CV AUC (SMOTE): 0.9286 ± 0.0050
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LGBM_smote_model.pkl
# 💾 Saved SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_LGBM_metrics_smote.json
# ⏱️  Runtime for LGBM: 11.33 minutes
# 🏁 MLflow run for 'LGBM' closed cleanly.
#
# 🔹 Running CatBoost...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for CatBoost...
#    Descriptive CV AUC: 0.7179 ± 0.0190
# 💾 Saved CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_CatBoost_model.pkl
# ✅ CatBoost done. Best params: {'clf__depth': 4, 'clf__iterations': 847, 'clf__l2_leaf_reg': 8, 'clf__learning_rate': 0.014223946814525337}
#    CV ROC-AUC: 0.718 ± 0.020
#    Holdout ROC-AUC: 0.734
# 💾 Saved non-SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_CatBoost_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7248
#    Performing descriptive StratifiedKFold CV on SMOTE training set for CatBoost...
#    Descriptive CV AUC (SMOTE): 0.9082 ± 0.0086
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_CatBoost_smote_model.pkl
# 💾 Saved SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_CatBoost_metrics_smote.json
# ⏱️  Runtime for CatBoost: 59.55 minutes
# 🏁 MLflow run for 'CatBoost' closed cleanly.
#
# 🔹 Running SVC...
# Fitting 50 folds for each of 32 candidates, totalling 1600 fits
#    Re-training best SVC with probability=True for calibrated AUROC...
#    Performing descriptive StratifiedKFold CV on original training set for SVC...
#    Descriptive CV AUC: 0.6610 ± 0.0074
# 💾 Saved SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_SVC_model.pkl
# ✅ SVC done. Best params: {'clf__C': 1, 'clf__gamma': 'scale', 'clf__kernel': 'rbf', 'clf__shrinking': True}
#    CV ROC-AUC: 0.664 ± 0.019
#    Holdout ROC-AUC: 0.688
# 💾 Saved non-SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_SVC_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6873
#    Performing descriptive StratifiedKFold CV on SMOTE training set for SVC...
#    Descriptive CV AUC (SMOTE): 0.8677 ± 0.0118
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_SVC_smote_model.pkl
# 💾 Saved SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_SVC_metrics_smote.json
# ⏱️  Runtime for SVC: 3.39 minutes
# 🏁 MLflow run for 'SVC' closed cleanly.
#
# 🔹 Running MLP...
# Fitting 50 folds for each of 4 candidates, totalling 200 fits
#    Performing descriptive StratifiedKFold CV on original training set for MLP...
#    Descriptive CV AUC: 0.6739 ± 0.0164
# 💾 Saved MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_MLP_model.pkl
# ✅ MLP done. Best params: {'clf__activation': 'relu', 'clf__alpha': 0.001, 'clf__early_stopping': True, 'clf__hidden_layer_sizes': (64,), 'clf__learning_rate_init': 0.001, 'clf__n_iter_no_change': 10, 'clf__solver': 'adam'}
#    CV ROC-AUC: 0.670 ± 0.022
#    Holdout ROC-AUC: 0.695
# 💾 Saved non-SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_MLP_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6700
#    Performing descriptive StratifiedKFold CV on SMOTE training set for MLP...
#    Descriptive CV AUC (SMOTE): 0.8086 ± 0.0405
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_MLP_smote_model.pkl
# 💾 Saved SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_MLP_metrics_smote.json
# ⏱️  Runtime for MLP: 0.14 minutes
# 🏁 MLflow run for 'MLP' closed cleanly.
#
# 🔹 Running NaiveBayes...
# Fitting 50 folds for each of 4 candidates, totalling 200 fits
#    Performing descriptive StratifiedKFold CV on original training set for NaiveBayes...
#    Descriptive CV AUC: 0.6740 ± 0.0132
# 💾 Saved NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_NaiveBayes_model.pkl
# ✅ NaiveBayes done. Best params: {'clf__var_smoothing': 1e-09}
#    CV ROC-AUC: 0.680 ± 0.020
#    Holdout ROC-AUC: 0.701
# 💾 Saved non-SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_NaiveBayes_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6819
#    Performing descriptive StratifiedKFold CV on SMOTE training set for NaiveBayes...
#    Descriptive CV AUC (SMOTE): 0.7028 ± 0.0175
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_NaiveBayes_smote_model.pkl
# 💾 Saved SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_NaiveBayes_metrics_smote.json
# ⏱️  Runtime for NaiveBayes: 0.01 minutes
# 🏁 MLflow run for 'NaiveBayes' closed cleanly.
#
# 📌 Evaluating all classifiers on holdout test set using CV-trained pipelines:
# LogisticRegression: Holdout ROC-AUC = 0.7237
# DecisionTree: Holdout ROC-AUC = 0.6213
# RandomForest: Holdout ROC-AUC = 0.7194
# GradientBoosting: Holdout ROC-AUC = 0.7209
# XGB: Holdout ROC-AUC = 0.7206
# LGBM: Holdout ROC-AUC = 0.7216
# CatBoost: Holdout ROC-AUC = 0.7284
# SVC: Holdout ROC-AUC = 0.6928
# MLP: Holdout ROC-AUC = 0.7077
# NaiveBayes: Holdout ROC-AUC = 0.7046
#
# 🏆 Best classifier (no SMOTE) = CatBoost, Holdout ROC-AUC = 0.7343
# 💾 Saved best model (no SMOTE) to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_best_model.pkl
# 🏆 Best SMOTE-trained classifier by holdout AUC = CatBoost, AUC = 0.7248
# 🎯 Final evaluation of best SMOTE-trained classifier = CatBoost, ROC-AUC = 0.7248
# 💾 Saved best SMOTE-trained model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_best_smote_model.pkl
# 💾 Saved final SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_best_smote_metrics.json
# 💾 Saved full summary including original and SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_full_summary_with_smote.csv
# 💾 Saved full results dict to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_full.pkl
# 💾 Saved all best SMOTE-trained classifiers to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\original_baseline_20251024_2113\original_baseline_20251024_2113_smote_full.pkl
# ⏱️  Total runtime for mode 'original_baseline': 124.71 minutes
#
# ---
#
# 🏁 MLflow run for 'original_baseline' closed cleanly.
# ✅ Summary exported to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\reports\20251024\original_baseline_summary.csv
# ✅ Finished model training for Original dataset.

# %% [markdown]
# ## 6. Train on Word2Vec Features
# The call to `repeated_cv_with_mixed_search()` runs both non-SMOTE and
# SMOTE-balanced training internally, logs results to MLflow, and saves
# artifacts to the appropriate `results/models/w2v/` folder.
#
# Run `repeated_cv_with_mixed_search`:
# - Hyperparameter search on non-SMOTE data
# - Retrain on SMOTE data with best params
# - Save models to `results/models/w2v/`
# - Evaluated on the holdout test set
# - Export summary to CSV + Markdown

# %%
X_train_w2v = datasets["w2v_radiology"]["X_train"]
X_test_w2v  = datasets["w2v_radiology"]["X_test"]
y_train_w2v = datasets["w2v_radiology"]["y_train"]
y_test_w2v  = datasets["w2v_radiology"]["y_test"]
X_train_smote_w2v = datasets["w2v_radiology"]["X_train_res"]
y_train_smote_w2v = datasets["w2v_radiology"]["y_train_res"]

results_w2v, summary_w2v = repeated_cv_with_mixed_search(
    X_train_w2v, y_train_w2v, X_test_w2v, y_test_w2v,
    classifiers=classifiers,
    param_spaces=param_spaces,
    X_train_smote=X_train_smote_w2v,
    y_train_smote=y_train_smote_w2v,
    n_splits=5,
    n_repeats=10,
    scoring=auc_scorer,
    n_iter_random=50,
    n_iter_random_per_clf=n_iter_random_per_clf,
    save_prefix="results/models/{mode}/",
    mode="w2v_radiology_baseline",
    log_mlflow=True
)

export_summary(summary_w2v, save_prefix="reports/", mode="w2v_radiology_baseline")
print("✅ Finished model training for Radiology Word2Vec dataset.")
# Out:
# ✅ MLflow tracking initialized under unified experiment 'Thesis_ModelTraining'
# Tracking URI: file:///C:/Users/tyler/OneDrive%20-%20University%20of%20Pittsburgh/BIOST%202021%20Thesis/Masters-Thesis/mlflow_tracking (Experiment ID: 169692831354922862)
#
# 🔹 Running LogisticRegression...
# Fitting 50 folds for each of 44 candidates, totalling 2200 fits
#    Performing descriptive StratifiedKFold CV on original training set for LogisticRegression...
#    Descriptive CV AUC: 0.7345 ± 0.0161
# 💾 Saved LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LogisticRegression_model.pkl
# ✅ LogisticRegression done. Best params: {'clf__C': 0.1, 'clf__l1_ratio': 0.5, 'clf__max_iter': 1000, 'clf__penalty': 'elasticnet', 'clf__solver': 'saga'}
#    CV ROC-AUC: 0.736 ± 0.017
#    Holdout ROC-AUC: 0.752
# 💾 Saved non-SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LogisticRegression_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7476
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LogisticRegression...
#    Descriptive CV AUC (SMOTE): 0.7787 ± 0.0127
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LogisticRegression_smote_model.pkl
# 💾 Saved SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LogisticRegression_metrics_smote.json
# ⏱️  Runtime for LogisticRegression: 3.67 minutes
# 🏁 MLflow run for 'LogisticRegression' closed cleanly.
#
# 🔹 Running DecisionTree...
# Fitting 50 folds for each of 240 candidates, totalling 12000 fits
#    Performing descriptive StratifiedKFold CV on original training set for DecisionTree...
#    Descriptive CV AUC: 0.6297 ± 0.0215
# 💾 Saved DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_DecisionTree_model.pkl
# ✅ DecisionTree done. Best params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__min_samples_leaf': 10, 'clf__min_samples_split': 2}
#    CV ROC-AUC: 0.630 ± 0.024
#    Holdout ROC-AUC: 0.598
# 💾 Saved non-SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_DecisionTree_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6361
#    Performing descriptive StratifiedKFold CV on SMOTE training set for DecisionTree...
#    Descriptive CV AUC (SMOTE): 0.7779 ± 0.0104
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_DecisionTree_smote_model.pkl
# 💾 Saved SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_DecisionTree_metrics_smote.json
# ⏱️  Runtime for DecisionTree: 5.62 minutes
# 🏁 MLflow run for 'DecisionTree' closed cleanly.
#
# 🔹 Running RandomForest...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for RandomForest...
#    Descriptive CV AUC: 0.7316 ± 0.0162
# 💾 Saved RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_RandomForest_model.pkl
# ✅ RandomForest done. Best params: {'clf__bootstrap': False, 'clf__max_depth': 10, 'clf__max_features': 'sqrt', 'clf__min_samples_leaf': 4, 'clf__min_samples_split': 10, 'clf__n_estimators': 356}
#    CV ROC-AUC: 0.728 ± 0.020
#    Holdout ROC-AUC: 0.733
# 💾 Saved non-SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_RandomForest_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7133
#    Performing descriptive StratifiedKFold CV on SMOTE training set for RandomForest...
#    Descriptive CV AUC (SMOTE): 0.9312 ± 0.0108
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_RandomForest_smote_model.pkl
# 💾 Saved SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_RandomForest_metrics_smote.json
# ⏱️  Runtime for RandomForest: 203.56 minutes
# 🏁 MLflow run for 'RandomForest' closed cleanly.
#
# 🔹 Running GradientBoosting...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for GradientBoosting...
#    Descriptive CV AUC: 0.7391 ± 0.0135
# 💾 Saved GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_GradientBoosting_model.pkl
# ✅ GradientBoosting done. Best params: {'clf__learning_rate': 0.019393987736667576, 'clf__max_depth': 5, 'clf__max_features': 'log2', 'clf__min_samples_leaf': 4, 'clf__min_samples_split': 3, 'clf__n_estimators': 301, 'clf__subsample': 0.9684482051282945}
#    CV ROC-AUC: 0.738 ± 0.017
#    Holdout ROC-AUC: 0.753
# 💾 Saved non-SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_GradientBoosting_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7213
#    Performing descriptive StratifiedKFold CV on SMOTE training set for GradientBoosting...
#    Descriptive CV AUC (SMOTE): 0.9167 ± 0.0102
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_GradientBoosting_smote_model.pkl
# 💾 Saved SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_GradientBoosting_metrics_smote.json
# ⏱️  Runtime for GradientBoosting: 51.32 minutes
# 🏁 MLflow run for 'GradientBoosting' closed cleanly.
#
# 🔹 Running XGB...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:13] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Performing descriptive StratifiedKFold CV on original training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:22] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:30] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:39] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:47] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:57:55] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC: 0.7480 ± 0.0160
# 💾 Saved XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_XGB_model.pkl
# ✅ XGB done. Best params: {'clf__colsample_bytree': 0.9454044297767479, 'clf__gamma': 0.4303652916281717, 'clf__learning_rate': 0.01208563915935721, 'clf__max_depth': 10, 'clf__min_child_weight': 3, 'clf__n_estimators': 848, 'clf__subsample': 0.8454489914076949}
#    CV ROC-AUC: 0.744 ± 0.017
#    Holdout ROC-AUC: 0.752
# 💾 Saved non-SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_XGB_metrics_non_smote.json
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:58:04] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    SMOTE Holdout ROC-AUC: 0.7420
#    Performing descriptive StratifiedKFold CV on SMOTE training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:58:16] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:58:28] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:58:39] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:58:51] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [07:59:03] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC (SMOTE): 0.9533 ± 0.0048
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_XGB_smote_model.pkl
# 💾 Saved SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_XGB_metrics_smote.json
# ⏱️  Runtime for XGB: 36.54 minutes
# 🏁 MLflow run for 'XGB' closed cleanly.
#
# 🔹 Running LGBM...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for LGBM...
#    Descriptive CV AUC: 0.7476 ± 0.0167
# 💾 Saved LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LGBM_model.pkl
# ✅ LGBM done. Best params: {'clf__colsample_bytree': 0.7880464524154114, 'clf__learning_rate': 0.014223946814525337, 'clf__max_depth': 20, 'clf__min_child_samples': 90, 'clf__n_estimators': 591, 'clf__num_leaves': 193, 'clf__subsample': 0.9370526621593617}
#    CV ROC-AUC: 0.743 ± 0.018
#    Holdout ROC-AUC: 0.750
# 💾 Saved non-SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LGBM_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7371
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LGBM...
#    Descriptive CV AUC (SMOTE): 0.9458 ± 0.0060
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LGBM_smote_model.pkl
# 💾 Saved SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_LGBM_metrics_smote.json
# ⏱️  Runtime for LGBM: 40.36 minutes
# 🏁 MLflow run for 'LGBM' closed cleanly.
#
# 🔹 Running CatBoost...
# Fitting 50 folds for each of 50 candidates, totalling 2500 fits
#    Performing descriptive StratifiedKFold CV on original training set for CatBoost...
#    Descriptive CV AUC: 0.7431 ± 0.0128
# 💾 Saved CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_CatBoost_model.pkl
# ✅ CatBoost done. Best params: {'clf__depth': 7, 'clf__iterations': 654, 'clf__l2_leaf_reg': 8, 'clf__learning_rate': 0.02031655633456552}
#    CV ROC-AUC: 0.744 ± 0.018
#    Holdout ROC-AUC: 0.757
# 💾 Saved non-SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_CatBoost_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7412
#    Performing descriptive StratifiedKFold CV on SMOTE training set for CatBoost...
#    Descriptive CV AUC (SMOTE): 0.9409 ± 0.0080
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_CatBoost_smote_model.pkl
# 💾 Saved SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_CatBoost_metrics_smote.json
# ⏱️  Runtime for CatBoost: 402.97 minutes
# 🏁 MLflow run for 'CatBoost' closed cleanly.
#
# 🔹 Running SVC...
# Fitting 50 folds for each of 32 candidates, totalling 1600 fits
#    Re-training best SVC with probability=True for calibrated AUROC...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#    Performing descriptive StratifiedKFold CV on original training set for SVC...
#    Descriptive CV AUC: 0.7098 ± 0.0086
# 💾 Saved SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_SVC_model.pkl
# ✅ SVC done. Best params: {'clf__C': 10, 'clf__gamma': 'scale', 'clf__kernel': 'linear', 'clf__shrinking': False}
#    CV ROC-AUC: 0.711 ± 0.017
#    Holdout ROC-AUC: 0.731
# 💾 Saved non-SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_SVC_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7338
#    Performing descriptive StratifiedKFold CV on SMOTE training set for SVC...
#    Descriptive CV AUC (SMOTE): 0.7750 ± 0.0128
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_SVC_smote_model.pkl
# 💾 Saved SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_SVC_metrics_smote.json
# ⏱️  Runtime for SVC: 826.10 minutes
# 🏁 MLflow run for 'SVC' closed cleanly.
#
# 🔹 Running MLP...
# Fitting 50 folds for each of 4 candidates, totalling 200 fits
#    Performing descriptive StratifiedKFold CV on original training set for MLP...
#    Descriptive CV AUC: 0.7267 ± 0.0115
# 💾 Saved MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_MLP_model.pkl
# ✅ MLP done. Best params: {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__early_stopping': True, 'clf__hidden_layer_sizes': (64,), 'clf__learning_rate_init': 0.001, 'clf__n_iter_no_change': 10, 'clf__solver': 'adam'}
#    CV ROC-AUC: 0.714 ± 0.026
#    Holdout ROC-AUC: 0.735
# 💾 Saved non-SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_MLP_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7059
#    Performing descriptive StratifiedKFold CV on SMOTE training set for MLP...
#    Descriptive CV AUC (SMOTE): 0.9034 ± 0.0093
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_MLP_smote_model.pkl
# 💾 Saved SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_MLP_metrics_smote.json
# ⏱️  Runtime for MLP: 0.38 minutes
# 🏁 MLflow run for 'MLP' closed cleanly.
#
# 🔹 Running NaiveBayes...
# Fitting 50 folds for each of 4 candidates, totalling 200 fits
#    Performing descriptive StratifiedKFold CV on original training set for NaiveBayes...
#    Descriptive CV AUC: 0.6634 ± 0.0200
# 💾 Saved NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_NaiveBayes_model.pkl
# ✅ NaiveBayes done. Best params: {'clf__var_smoothing': 1e-09}
#    CV ROC-AUC: 0.664 ± 0.018
#    Holdout ROC-AUC: 0.673
# 💾 Saved non-SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_NaiveBayes_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6491
#    Performing descriptive StratifiedKFold CV on SMOTE training set for NaiveBayes...
#    Descriptive CV AUC (SMOTE): 0.7222 ± 0.0133
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_NaiveBayes_smote_model.pkl
# 💾 Saved SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_NaiveBayes_metrics_smote.json
# ⏱️  Runtime for NaiveBayes: 0.02 minutes
# 🏁 MLflow run for 'NaiveBayes' closed cleanly.
#
# 📌 Evaluating all classifiers on holdout test set using CV-trained pipelines:
# LogisticRegression: Holdout ROC-AUC = 0.7549
# DecisionTree: Holdout ROC-AUC = 0.6125
# RandomForest: Holdout ROC-AUC = 0.7285
# GradientBoosting: Holdout ROC-AUC = 0.7355
# XGB: Holdout ROC-AUC = 0.7470
# LGBM: Holdout ROC-AUC = 0.7363
# CatBoost: Holdout ROC-AUC = 0.7547
# SVC: Holdout ROC-AUC = 0.7467
# MLP: Holdout ROC-AUC = 0.7384
# NaiveBayes: Holdout ROC-AUC = 0.6773
#
# 🏆 Best classifier (no SMOTE) = CatBoost, Holdout ROC-AUC = 0.7568
# 💾 Saved best model (no SMOTE) to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_best_model.pkl
# 🏆 Best SMOTE-trained classifier by holdout AUC = LogisticRegression, AUC = 0.7476
# 🎯 Final evaluation of best SMOTE-trained classifier = LogisticRegression, ROC-AUC = 0.7476
# 💾 Saved best SMOTE-trained model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_best_smote_model.pkl
# 💾 Saved final SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_best_smote_metrics.json
# 💾 Saved full summary including original and SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_full_summary_with_smote.csv
# 💾 Saved full results dict to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_full.pkl
# 💾 Saved all best SMOTE-trained classifiers to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\{mode}\w2v_radiology_baseline_20251025_0258\w2v_radiology_baseline_20251025_0258_smote_full.pkl
# ⏱️  Total runtime for mode 'w2v_radiology_baseline': 1570.70 minutes
#
# ---
#
# 🏁 MLflow run for 'w2v_radiology_baseline' closed cleanly.
# ✅ Summary exported to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\reports\20251026\w2v_radiology_baseline_summary.csv
# ✅ Finished model training for Radiology Word2Vec dataset.

# %% [markdown]
# ## 7: (Optional) Future Variants — Discharge & Combined
#
# To extend training later, uncomment and adapt the same pattern for:
# - `datasets["w2v_dis"]`
# - `datasets["w2v_comb"]`
#
# Each should call `repeated_cv_with_mixed_search()` with appropriate paths:
# `save_prefix="results/models/w2v_dis/"` and `"results/models/w2v_comb/"`.

# %%
# ==================================================
# [Optional] Train classifiers for Discharge and Combined variants
# ==================================================
# for variant in ["w2v_dis", "w2v_comb"]:
#     data = datasets[variant]
#     print(f"\n🧠 Training classifiers for {variant.upper()} variant")
#
#     results_orig, summary_orig = repeated_cv_with_mixed_search(
#         data["X_train"], data["y_train"], data["X_test"], data["y_test"],
#         classifiers, param_spaces,
#         descriptive_cv=True,
#         mode=variant
#     )
#
#     results_smote, summary_smote = repeated_cv_with_mixed_search(
#         data["X_train"], data["y_train"], data["X_test"], data["y_test"],
#         classifiers, param_spaces,
#         X_train_smote=data["X_train_res"],
#         y_train_smote=data["y_train_res"],
#         descriptive_cv=True,
#         mode=f"{variant}_smote"
#     )
#
#     results_all[variant] = {
#         "non_smote": summary_orig,
#         "smote": summary_smote
#     }

# %% [markdown]
# ## 8. Baseline Comparison Summary
#
# Merge and compare model performance summaries across all available feature variants.
# Results are saved under `results/reports/` and optionally logged to MLflow.

# %%
import os
import pandas as pd
from src.utils import resolve_path

# --- Tag datasets for clarity ---
summary_orig["Dataset"] = "original"
summary_w2v["Dataset"] = "w2v_radiology"

# Optional: add discharge/combined if available
if "summary_w2v_dis" in globals():
    summary_w2v_dis["Dataset"] = "w2v_discharge"

if "summary_w2v_comb" in globals():
    summary_w2v_comb["Dataset"] = "w2v_combined"

# --- Merge all summaries into one DataFrame ---
all_summaries = [summary_orig, summary_w2v]

if "summary_w2v_dis" in globals():
    all_summaries.append(summary_w2v_dis)

if "summary_w2v_comb" in globals():
    all_summaries.append(summary_w2v_comb)

baseline_summary = pd.concat(all_summaries, axis=0)

# --- Save merged comparison summary ---
baseline_summary_path = resolve_path("results/reports/baseline_comparison.csv")
os.makedirs(os.path.dirname(baseline_summary_path), exist_ok=True)
baseline_summary.to_csv(baseline_summary_path, index=False)

print(f"💾 Saved merged baseline summary to {baseline_summary_path}")

# --- Optional: Log to MLflow ---
if "mlflow" in globals():
    mlflow.log_artifact(baseline_summary_path, artifact_path="summaries")
    print(f"📤 Logged baseline comparison summary to MLflow at 'summaries/'")

# --- Display tidy summary table ---
cols_to_display = [
    "Dataset",
    "Classifier",
    "Holdout ROC-AUC",
    "Holdout Precision",
    "Holdout Recall",
    "Holdout F1",
    "Holdout ROC-AUC (SMOTE)",
    "Final Holdout ROC-AUC (SMOTE)",
]

display(baseline_summary[[c for c in cols_to_display if c in baseline_summary.columns]])
# Out:
# 💾 Saved merged baseline summary to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\reports\baseline_comparison.csv
#          Dataset          Classifier  Holdout ROC-AUC  Holdout Precision  \
# 6       original            CatBoost         0.734284           0.545455
# 4       original                 XGB         0.728923           0.535714
# 3       original    GradientBoosting         0.726701           0.551020
# 2       original        RandomForest         0.726405           0.916667
# 5       original                LGBM         0.725975           0.482759
# 0       original  LogisticRegression         0.723406           0.483333
# 9       original          NaiveBayes         0.701084           0.406844
# 8       original                 MLP         0.694930           0.433333
# 7       original                 SVC         0.688066           0.777778
# 1       original        DecisionTree         0.634860           0.516667
# 6  w2v_radiology            CatBoost         0.756803           0.561404
# 3  w2v_radiology    GradientBoosting         0.753368           0.551020
# 0  w2v_radiology  LogisticRegression         0.752343           0.586667
# 4  w2v_radiology                 XGB         0.752203           0.532258
# 5  w2v_radiology                LGBM         0.749913           0.565217
# 8  w2v_radiology                 MLP         0.735248           0.522727
# 2  w2v_radiology        RandomForest         0.732508           0.875000
# 7  w2v_radiology                 SVC         0.731005           0.000000
# 9  w2v_radiology          NaiveBayes         0.673220           0.333333
# 1  w2v_radiology        DecisionTree         0.597655           0.357143
#
#    Holdout Recall  Holdout F1  Holdout ROC-AUC (SMOTE)  \
# 6        0.124481    0.202703                 0.724805
# 4        0.124481    0.202020                 0.712693
# 3        0.112033    0.186207                 0.703203
# 2        0.045643    0.086957                 0.702074
# 5        0.174274    0.256098                 0.709917
# 0        0.120332    0.192691                 0.716185
# 9        0.443983    0.424603                 0.681948
# 8        0.107884    0.172757                 0.669951
# 7        0.029046    0.056000                 0.687258
# 1        0.128631    0.205980                 0.629568
# 6        0.132780    0.214765                 0.741247
# 3        0.112033    0.186207                 0.721349
# 0        0.182573    0.278481                 0.747577
# 4        0.136929    0.217822                 0.741951
# 5        0.161826    0.251613                 0.737128
# 8        0.190871    0.279635                 0.705897
# 2        0.029046    0.056225                 0.713325
# 7        0.000000    0.000000                 0.733808
# 9        0.630705    0.436155                 0.649106
# 1        0.062241    0.106007                 0.636051
#
#   Final Holdout ROC-AUC (SMOTE)
# 6                      0.724805
# 4                          None
# 3                          None
# 2                          None
# 5                          None
# 0                          None
# 9                          None
# 8                          None
# 7                          None
# 1                          None
# 6                          None
# 3                          None
# 0                      0.747577
# 4                          None
# 5                          None
# 8                          None
# 2                          None
# 7                          None
# 9                          None
# 1                          None

# %% [markdown]
# ## 9. Completion
# Models and results are saved to:
# - `results/models/original/`
# - `results/models/w2v/`
# - `reports/`

# %%
print("✅ Training complete. Models + summaries saved to ../results/models/ and ../results/reports/")
# Out:
# ✅ Training complete. Models + summaries saved to ../results/models/ and ../results/reports/

# %%
'''
Troubleshooting step for SVC, MLP, and NB

# --- Test on SVC, MLP, and NB ---
X_train_orig = datasets["original"]["X_train"]
X_test_orig  = datasets["original"]["X_test"]
y_train_orig = datasets["original"]["y_train"]
y_test_orig  = datasets["original"]["y_test"]
X_train_smote_orig = datasets["original"]["X_train_res"]
y_train_smote_orig = datasets["original"]["y_train_res"]

# --- Restrict classifiers to SVC, MLP, and Naive Bayes only ---
subset_classifiers = {k: v for k, v in classifiers.items() if k in ["SVC", "MLP", "NaiveBayes"]}

# --- Restrict param spaces accordingly ---
subset_param_spaces = {k: v for k, v in param_spaces.items() if k in ["SVC", "MLP", "NaiveBayes"]}

# --- Run cross-validation and SMOTE retraining just for these three ---
results_orig, summary_orig = repeated_cv_with_mixed_search(
    X_train_orig, y_train_orig, X_test_orig, y_test_orig,
    classifiers=subset_classifiers,
    param_spaces=subset_param_spaces,
    X_train_smote=X_train_smote_orig,
    y_train_smote=y_train_smote_orig,
    n_splits=5,
    n_repeats=10,
    scoring=auc_scorer,
    n_iter_random=50,
    n_iter_random_per_clf=n_iter_random_per_clf,
    save_prefix="results/models/original/",
    mode="original_svc_mlp_nb",
    log_mlflow=True
)

export_summary(summary_orig, save_prefix="reports/", mode="original_svc_mlp_nb")
print("✅ Finished model training for Original dataset (SVC, MLP, NB only).")
'''

# %%
'''
# --- Minimal Dry Run: Radiology Word2Vec ---

# 1️⃣ Load W2V Radiology datasets
X_train_w2v = datasets["w2v_radiology"]["X_train"]
X_test_w2v  = datasets["w2v_radiology"]["X_test"]
y_train_w2v = datasets["w2v_radiology"]["y_train"]
y_test_w2v  = datasets["w2v_radiology"]["y_test"]
X_train_smote_w2v = datasets["w2v_radiology"]["X_train_res"]
y_train_smote_w2v = datasets["w2v_radiology"]["y_train_res"]

# 2️⃣ Define a one-point param grid for each classifier
param_spaces_dryrun = {
    "LogisticRegression": {
        "clf__penalty": ["l2"],
        "clf__solver": ["lbfgs"],
        "clf__C": [1.0],
        "clf__max_iter": [100]
    },
    "DecisionTree": {
        "clf__max_depth": [5]
    },
    "RandomForest": {
        "clf__n_estimators": [10],
        "clf__max_depth": [5]
    },
    "GradientBoosting": {
        "clf__n_estimators": [10],
        "clf__learning_rate": [0.1],
        "clf__max_depth": [3]
    },
    "XGB": {
        "clf__n_estimators": [10],
        "clf__learning_rate": [0.1],
        "clf__max_depth": [3]
    },
    "LGBM": {
        "clf__n_estimators": [10],
        "clf__learning_rate": [0.1],
        "clf__max_depth": [3]
    },
    "CatBoost": {
        "clf__iterations": [10],
        "clf__depth": [3],
        "clf__learning_rate": [0.1]
    },
    "SVC": {
        "clf__C": [1.0],
        "clf__kernel": ["linear"]
    },
    "MLP": {
        "clf__hidden_layer_sizes": [(8,)],
        "clf__activation": ["relu"],
        "clf__max_iter": [100]
    },
    "NaiveBayes": {
        "clf__var_smoothing": [1e-9]
    }
}

# 3️⃣ Minimal iterations/repeats
n_iter_random_per_clf_dryrun = {name: 1 for name in param_spaces_dryrun.keys()}

# 4️⃣ Run minimal test (no MLflow, single repeat, one candidate each)
results_dryrun, summary_dryrun = repeated_cv_with_mixed_search(
    X_train_w2v, y_train_w2v, X_test_w2v, y_test_w2v,
    classifiers=classifiers,
    param_spaces=param_spaces_dryrun,
    X_train_smote=X_train_smote_w2v,
    y_train_smote=y_train_smote_w2v,
    n_splits=2,           # reduce folds for speed
    n_repeats=1,
    scoring=auc_scorer,
    n_iter_random=1,
    n_iter_random_per_clf=n_iter_random_per_clf_dryrun,
    save_prefix="results/models/dryrun/",
    mode="dry_run",
    log_mlflow=False
)
'''
# Out:
# 🔹 Running LogisticRegression...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for LogisticRegression...
#    Descriptive CV AUC: 0.7246 ± 0.0136
# 💾 Saved LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LogisticRegression_model.pkl
# ✅ LogisticRegression done. Best params: {'clf__C': 1.0, 'clf__max_iter': 100, 'clf__penalty': 'l2', 'clf__solver': 'lbfgs'}
#    CV ROC-AUC: 0.7077 ± 0.005
#    Holdout ROC-AUC: 0.7434
# 💾 Saved non-SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LogisticRegression_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7399
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LogisticRegression...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#    Descriptive CV AUC (SMOTE): 0.7771 ± 0.0127
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LogisticRegression_smote_model.pkl
# 💾 Saved SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LogisticRegression_metrics_smote.json
# ⏱️  Runtime for LogisticRegression: 0.13 minutes
#
# 🔹 Running DecisionTree...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for DecisionTree...
#    Descriptive CV AUC: 0.6248 ± 0.0235
# 💾 Saved DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_DecisionTree_model.pkl
# ✅ DecisionTree done. Best params: {'clf__max_depth': 5}
#    CV ROC-AUC: 0.6107 ± 0.024
#    Holdout ROC-AUC: 0.6092
# 💾 Saved non-SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_DecisionTree_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6348
#    Performing descriptive StratifiedKFold CV on SMOTE training set for DecisionTree...
#    Descriptive CV AUC (SMOTE): 0.7767 ± 0.0131
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_DecisionTree_smote_model.pkl
# 💾 Saved SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_DecisionTree_metrics_smote.json
# ⏱️  Runtime for DecisionTree: 0.12 minutes
#
# 🔹 Running RandomForest...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for RandomForest...
#    Descriptive CV AUC: 0.6798 ± 0.0154
# 💾 Saved RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_RandomForest_model.pkl
# ✅ RandomForest done. Best params: {'clf__n_estimators': 10, 'clf__max_depth': 5}
#    CV ROC-AUC: 0.6749 ± 0.003
#    Holdout ROC-AUC: 0.6814
# 💾 Saved non-SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_RandomForest_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7032
#    Performing descriptive StratifiedKFold CV on SMOTE training set for RandomForest...
#    Descriptive CV AUC (SMOTE): 0.8212 ± 0.0233
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_RandomForest_smote_model.pkl
# 💾 Saved SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_RandomForest_metrics_smote.json
# ⏱️  Runtime for RandomForest: 0.14 minutes
#
# 🔹 Running GradientBoosting...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for GradientBoosting...
#    Descriptive CV AUC: 0.7001 ± 0.0196
# 💾 Saved GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_GradientBoosting_model.pkl
# ✅ GradientBoosting done. Best params: {'clf__n_estimators': 10, 'clf__max_depth': 3, 'clf__learning_rate': 0.1}
#    CV ROC-AUC: 0.6905 ± 0.004
#    Holdout ROC-AUC: 0.6953
# 💾 Saved non-SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_GradientBoosting_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6787
#    Performing descriptive StratifiedKFold CV on SMOTE training set for GradientBoosting...
#    Descriptive CV AUC (SMOTE): 0.8443 ± 0.0204
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_GradientBoosting_smote_model.pkl
# 💾 Saved SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_GradientBoosting_metrics_smote.json
# ⏱️  Runtime for GradientBoosting: 0.40 minutes
#
# 🔹 Running XGB...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Performing descriptive StratifiedKFold CV on original training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC: 0.6983 ± 0.0189
# 💾 Saved XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_XGB_model.pkl
# ✅ XGB done. Best params: {'clf__n_estimators': 10, 'clf__max_depth': 3, 'clf__learning_rate': 0.1}
#    CV ROC-AUC: 0.6932 ± 0.005
#    Holdout ROC-AUC: 0.69
# 💾 Saved non-SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_XGB_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6722
#    Performing descriptive StratifiedKFold CV on SMOTE training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [12:13:44] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC (SMOTE): 0.8369 ± 0.0187
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_XGB_smote_model.pkl
# 💾 Saved SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_XGB_metrics_smote.json
# ⏱️  Runtime for XGB: 0.08 minutes
#
# 🔹 Running LGBM...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for LGBM...
#    Descriptive CV AUC: 0.6978 ± 0.0173
# 💾 Saved LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LGBM_model.pkl
# ✅ LGBM done. Best params: {'clf__n_estimators': 10, 'clf__max_depth': 3, 'clf__learning_rate': 0.1}
#    CV ROC-AUC: 0.6991 ± 0.001
#    Holdout ROC-AUC: 0.7045
# 💾 Saved non-SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LGBM_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6727
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LGBM...
#    Descriptive CV AUC (SMOTE): 0.8448 ± 0.0213
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LGBM_smote_model.pkl
# 💾 Saved SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_LGBM_metrics_smote.json
# ⏱️  Runtime for LGBM: 0.10 minutes
#
# 🔹 Running CatBoost...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#    Performing descriptive StratifiedKFold CV on original training set for CatBoost...
#    Descriptive CV AUC: 0.6765 ± 0.0153
# 💾 Saved CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_CatBoost_model.pkl
# ✅ CatBoost done. Best params: {'clf__learning_rate': 0.1, 'clf__iterations': 10, 'clf__depth': 3}
#    CV ROC-AUC: 0.6783 ± 0.012
#    Holdout ROC-AUC: 0.687
# 💾 Saved non-SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_CatBoost_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6741
#    Performing descriptive StratifiedKFold CV on SMOTE training set for CatBoost...
#    Descriptive CV AUC (SMOTE): 0.8371 ± 0.0180
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_CatBoost_smote_model.pkl
# 💾 Saved SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_CatBoost_metrics_smote.json
# ⏱️  Runtime for CatBoost: 0.08 minutes
#
# 🔹 Running SVC...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Re-training best SVC with probability=True for calibrated AUROC...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#    Performing descriptive StratifiedKFold CV on original training set for SVC...
#    Descriptive CV AUC: 0.6855 ± 0.0166
# 💾 Saved SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_SVC_model.pkl
# ✅ SVC done. Best params: {'clf__C': 1.0, 'clf__kernel': 'linear'}
#    CV ROC-AUC: 0.6908 ± 0.009
#    Holdout ROC-AUC: 0.6758
# 💾 Saved non-SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_SVC_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7344
#    Performing descriptive StratifiedKFold CV on SMOTE training set for SVC...
#    Descriptive CV AUC (SMOTE): 0.7755 ± 0.0126
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_SVC_smote_model.pkl
# 💾 Saved SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_SVC_metrics_smote.json
# ⏱️  Runtime for SVC: 4.07 minutes
#
# 🔹 Running MLP...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
#    Performing descriptive StratifiedKFold CV on original training set for MLP...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
#    Descriptive CV AUC: 0.7269 ± 0.0130
# 💾 Saved MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_MLP_model.pkl
# ✅ MLP done. Best params: {'clf__activation': 'relu', 'clf__hidden_layer_sizes': (8,), 'clf__max_iter': 100}
#    CV ROC-AUC: 0.7078 ± 0.005
#    Holdout ROC-AUC: 0.7299
# 💾 Saved non-SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_MLP_metrics_non_smote.json
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
#    SMOTE Holdout ROC-AUC: 0.7394
#    Performing descriptive StratifiedKFold CV on SMOTE training set for MLP...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:781: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
#    Descriptive CV AUC (SMOTE): 0.8131 ± 0.0129
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_MLP_smote_model.pkl
# 💾 Saved SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_MLP_metrics_smote.json
# ⏱️  Runtime for MLP: 0.19 minutes
#
# 🔹 Running NaiveBayes...
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
#    Performing descriptive StratifiedKFold CV on original training set for NaiveBayes...
#    Descriptive CV AUC: 0.6634 ± 0.0200
# 💾 Saved NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_NaiveBayes_model.pkl
# ✅ NaiveBayes done. Best params: {'clf__var_smoothing': 1e-09}
#    CV ROC-AUC: 0.6547 ± 0.005
#    Holdout ROC-AUC: 0.6732
# 💾 Saved non-SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_NaiveBayes_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6491
#    Performing descriptive StratifiedKFold CV on SMOTE training set for NaiveBayes...
#    Descriptive CV AUC (SMOTE): 0.7222 ± 0.0133
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_NaiveBayes_smote_model.pkl
# 💾 Saved SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_NaiveBayes_metrics_smote.json
# ⏱️  Runtime for NaiveBayes: 0.07 minutes
#
# 📌 Evaluating all classifiers on holdout test set using CV-trained pipelines:
# LogisticRegression: Holdout ROC-AUC = 0.7434
# DecisionTree: Holdout ROC-AUC = 0.6092
# RandomForest: Holdout ROC-AUC = 0.6814
# GradientBoosting: Holdout ROC-AUC = 0.6953
# XGB: Holdout ROC-AUC = 0.6900
# LGBM: Holdout ROC-AUC = 0.7045
# CatBoost: Holdout ROC-AUC = 0.6870
# SVC: Holdout ROC-AUC = 0.6758
# MLP: Holdout ROC-AUC = 0.7299
# NaiveBayes: Holdout ROC-AUC = 0.6732
#
# 🏆 Best classifier (no SMOTE) = LogisticRegression, Holdout ROC-AUC = 0.7434
# 💾 Saved best model (no SMOTE) to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_best_model.pkl
# 🏆 Best SMOTE-trained classifier by holdout AUC = LogisticRegression, AUC = 0.7399
# 🎯 Final evaluation of best SMOTE-trained classifier = LogisticRegression, ROC-AUC = 0.7399
# 💾 Saved best SMOTE-trained model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_best_smote_model.pkl
# 💾 Saved final SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_best_smote_metrics.json
# 💾 Saved full summary including original and SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_full_summary_with_smote.csv
# 💾 Saved full results dict to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_full.pkl
# 💾 Saved all best SMOTE-trained classifiers to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\dryrun\dry_run_20251026_1212\dry_run_20251026_1212_smote_full.pkl
# ⏱️  Total runtime for mode 'dry_run': 5.40 minutes
#
# ---

# %%
# ==================================================
# 🚀 Refit Final Models Using Best Parameters (Original Structured Data)
# ==================================================
import os
from src.models import (
    get_classifiers,
    repeated_cv_with_mixed_search,
    auc_scorer
)
from src.utils import resolve_path
from src.evaluation import export_summary

# --------------------------------------------------
# 1️⃣  Define best parameters from your 20251024_2113 run
# --------------------------------------------------
param_spaces_fixed = {
    "LogisticRegression": [{
        "clf__C": [0.01],
        "clf__penalty": ["l2"],
        "clf__solver": ["liblinear"],
        "clf__max_iter": [1000]
    }],
    "DecisionTree": [{
        "clf__criterion": ["gini"],
        "clf__max_depth": [5],
        "clf__min_samples_leaf": [10],
        "clf__min_samples_split": [2]
    }],
    "RandomForest": [{
        "clf__bootstrap": [True],
        "clf__max_depth": [10],
        "clf__max_features": ["log2"],
        "clf__min_samples_leaf": [4],
        "clf__min_samples_split": [7],
        "clf__n_estimators": [935]
    }],
    "GradientBoosting": [{
        "clf__learning_rate": [0.013979488347959958],
        "clf__max_depth": [3],
        "clf__max_features": ["log2"],
        "clf__min_samples_leaf": [2],
        "clf__min_samples_split": [10],
        "clf__n_estimators": [445],
        "clf__subsample": [0.7293016342019151]
    }],
    "XGB": [{
        "clf__colsample_bytree": [0.9165996316800473],
        "clf__gamma": [0.4692763545078751],
        "clf__learning_rate": [0.010233629752304298],
        "clf__max_depth": [6],
        "clf__min_child_weight": [5],
        "clf__n_estimators": [360],
        "clf__subsample": [0.7912726728878613]
    }],
    "LGBM": [{
        "clf__colsample_bytree": [0.7880464524154114],
        "clf__learning_rate": [0.014223946814525337],
        "clf__max_depth": [20],
        "clf__min_child_samples": [90],
        "clf__n_estimators": [591],
        "clf__num_leaves": [193],
        "clf__subsample": [0.9370526621593617]
    }],
    "CatBoost": [{
        "clf__depth": [4],
        "clf__iterations": [847],
        "clf__l2_leaf_reg": [8],
        "clf__learning_rate": [0.014223946814525337]
    }],
    "SVC": [{
        "clf__C": [1],
        "clf__gamma": ["scale"],
        "clf__kernel": ["rbf"],
        "clf__shrinking": [True]
    }],
    "MLP": [{
        "clf__activation": ["relu"],
        "clf__alpha": [0.001],
        "clf__early_stopping": [True],
        "clf__hidden_layer_sizes": [(64,)],
        "clf__learning_rate_init": [0.001],
        "clf__n_iter_no_change": [10],
        "clf__solver": ["adam"]
    }],
    "NaiveBayes": [{
        "clf__var_smoothing": [1e-9]
    }]
}

# --------------------------------------------------
# 2️⃣  Prepare fixed iteration configuration
# --------------------------------------------------
n_iter_random_per_clf_fixed = {k: 1 for k in param_spaces_fixed.keys()}

# --------------------------------------------------
# 3️⃣  Load structured-only dataset (original)
# --------------------------------------------------
X_train_orig = datasets["original"]["X_train"]
X_test_orig  = datasets["original"]["X_test"]
y_train_orig = datasets["original"]["y_train"]
y_test_orig  = datasets["original"]["y_test"]
X_train_smote_orig = datasets["original"]["X_train_res"]
y_train_smote_orig = datasets["original"]["y_train_res"]

# --------------------------------------------------
# 4️⃣  Run refit (no hyperparameter search, one fit per model)
# --------------------------------------------------
results_orig_refit, summary_orig_refit = repeated_cv_with_mixed_search(
    X_train_orig, y_train_orig, X_test_orig, y_test_orig,
    classifiers=get_classifiers(),
    param_spaces=param_spaces_fixed,
    X_train_smote=X_train_smote_orig,
    y_train_smote=y_train_smote_orig,
    n_splits=5,
    n_repeats=10,
    scoring=auc_scorer,
    n_iter_random=1,
    n_iter_random_per_clf=n_iter_random_per_clf_fixed,
    descriptive_cv=True,
    save_prefix="results/models/original_baseline/",
    mode="original_baseline",
    log_mlflow=True
)

# --------------------------------------------------
# 5️⃣  Export summary
# --------------------------------------------------
export_summary(summary_orig_refit, save_prefix="reports/20251026_NEW", mode="original_baseline")
print("✅ Finished model refit for Original Structured dataset.")
# Out:
# ✅ MLflow tracking initialized under unified experiment 'Thesis_ModelTraining'
# Tracking URI: file:///C:/Users/tyler/OneDrive%20-%20University%20of%20Pittsburgh/BIOST%202021%20Thesis/Masters-Thesis/mlflow_tracking (Experiment ID: 169692831354922862)
#
# 🔹 Running LogisticRegression...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\linear_model\_logistic.py:1305: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 24.
#   warnings.warn(
#    Performing descriptive StratifiedKFold CV on original training set for LogisticRegression...
#    Descriptive CV AUC: 0.7039 ± 0.0140
# 💾 Saved LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LogisticRegression_model.pkl
# ✅ LogisticRegression done. Best params: {'clf__C': 0.01, 'clf__max_iter': 1000, 'clf__penalty': 'l2', 'clf__solver': 'liblinear'}
#    CV ROC-AUC: 0.7058 ± 0.018
#    Holdout ROC-AUC: 0.7234
# 💾 Saved non-SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LogisticRegression_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7162
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LogisticRegression...
#    Descriptive CV AUC (SMOTE): 0.7243 ± 0.0159
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LogisticRegression_smote_model.pkl
# 💾 Saved SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LogisticRegression_metrics_smote.json
# ⏱️  Runtime for LogisticRegression: 0.16 minutes
# 🏁 MLflow run for 'LogisticRegression' closed cleanly.
#
# 🔹 Running DecisionTree...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for DecisionTree...
#    Descriptive CV AUC: 0.6620 ± 0.0165
# 💾 Saved DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_DecisionTree_model.pkl
# ✅ DecisionTree done. Best params: {'clf__criterion': 'gini', 'clf__max_depth': 5, 'clf__min_samples_leaf': 10, 'clf__min_samples_split': 2}
#    CV ROC-AUC: 0.6427 ± 0.023
#    Holdout ROC-AUC: 0.6349
# 💾 Saved non-SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_DecisionTree_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6296
#    Performing descriptive StratifiedKFold CV on SMOTE training set for DecisionTree...
#    Descriptive CV AUC (SMOTE): 0.7271 ± 0.0135
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_DecisionTree_smote_model.pkl
# 💾 Saved SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_DecisionTree_metrics_smote.json
# ⏱️  Runtime for DecisionTree: 0.02 minutes
# 🏁 MLflow run for 'DecisionTree' closed cleanly.
#
# 🔹 Running RandomForest...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for RandomForest...
#    Descriptive CV AUC: 0.7197 ± 0.0206
# 💾 Saved RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_RandomForest_model.pkl
# ✅ RandomForest done. Best params: {'clf__n_estimators': 935, 'clf__min_samples_split': 7, 'clf__min_samples_leaf': 4, 'clf__max_features': 'log2', 'clf__max_depth': 10, 'clf__bootstrap': True}
#    CV ROC-AUC: 0.7199 ± 0.021
#    Holdout ROC-AUC: 0.7264
# 💾 Saved non-SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_RandomForest_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7021
#    Performing descriptive StratifiedKFold CV on SMOTE training set for RandomForest...
#    Descriptive CV AUC (SMOTE): 0.8901 ± 0.0135
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_RandomForest_smote_model.pkl
# 💾 Saved SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_RandomForest_metrics_smote.json
# ⏱️  Runtime for RandomForest: 1.53 minutes
# 🏁 MLflow run for 'RandomForest' closed cleanly.
#
# 🔹 Running GradientBoosting...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for GradientBoosting...
#    Descriptive CV AUC: 0.7155 ± 0.0210
# 💾 Saved GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_GradientBoosting_model.pkl
# ✅ GradientBoosting done. Best params: {'clf__subsample': 0.7293016342019151, 'clf__n_estimators': 445, 'clf__min_samples_split': 10, 'clf__min_samples_leaf': 2, 'clf__max_features': 'log2', 'clf__max_depth': 3, 'clf__learning_rate': 0.013979488347959958}
#    CV ROC-AUC: 0.7170 ± 0.020
#    Holdout ROC-AUC: 0.7267
# 💾 Saved non-SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_GradientBoosting_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7032
#    Performing descriptive StratifiedKFold CV on SMOTE training set for GradientBoosting...
#    Descriptive CV AUC (SMOTE): 0.8489 ± 0.0151
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_GradientBoosting_smote_model.pkl
# 💾 Saved SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_GradientBoosting_metrics_smote.json
# ⏱️  Runtime for GradientBoosting: 0.35 minutes
# 🏁 MLflow run for 'GradientBoosting' closed cleanly.
#
# 🔹 Running XGB...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:19] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Performing descriptive StratifiedKFold CV on original training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:19] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:20] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:20] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:21] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:21] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC: 0.7184 ± 0.0177
# 💾 Saved XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_XGB_model.pkl
# ✅ XGB done. Best params: {'clf__subsample': 0.7912726728878613, 'clf__n_estimators': 360, 'clf__min_child_weight': 5, 'clf__max_depth': 6, 'clf__learning_rate': 0.010233629752304298, 'clf__gamma': 0.4692763545078751, 'clf__colsample_bytree': 0.9165996316800473}
#    CV ROC-AUC: 0.7173 ± 0.019
#    Holdout ROC-AUC: 0.7289
# 💾 Saved non-SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_XGB_metrics_non_smote.json
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:22] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    SMOTE Holdout ROC-AUC: 0.7127
#    Performing descriptive StratifiedKFold CV on SMOTE training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:23] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:23] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:24] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:25] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [08:20:26] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC (SMOTE): 0.9106 ± 0.0083
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_XGB_smote_model.pkl
# 💾 Saved SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_XGB_metrics_smote.json
# ⏱️  Runtime for XGB: 0.19 minutes
# 🏁 MLflow run for 'XGB' closed cleanly.
#
# 🔹 Running LGBM...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for LGBM...
#    Descriptive CV AUC: 0.7069 ± 0.0161
# 💾 Saved LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LGBM_model.pkl
# ✅ LGBM done. Best params: {'clf__subsample': 0.9370526621593617, 'clf__num_leaves': 193, 'clf__n_estimators': 591, 'clf__min_child_samples': 90, 'clf__max_depth': 20, 'clf__learning_rate': 0.014223946814525337, 'clf__colsample_bytree': 0.7880464524154114}
#    CV ROC-AUC: 0.7058 ± 0.017
#    Holdout ROC-AUC: 0.726
# 💾 Saved non-SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LGBM_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7099
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LGBM...
#    Descriptive CV AUC (SMOTE): 0.9286 ± 0.0050
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LGBM_smote_model.pkl
# 💾 Saved SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_LGBM_metrics_smote.json
# ⏱️  Runtime for LGBM: 0.36 minutes
# 🏁 MLflow run for 'LGBM' closed cleanly.
#
# 🔹 Running CatBoost...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for CatBoost...
#    Descriptive CV AUC: 0.7179 ± 0.0190
# 💾 Saved CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_CatBoost_model.pkl
# ✅ CatBoost done. Best params: {'clf__learning_rate': 0.014223946814525337, 'clf__l2_leaf_reg': 8, 'clf__iterations': 847, 'clf__depth': 4}
#    CV ROC-AUC: 0.7177 ± 0.020
#    Holdout ROC-AUC: 0.7343
# 💾 Saved non-SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_CatBoost_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7248
#    Performing descriptive StratifiedKFold CV on SMOTE training set for CatBoost...
#    Descriptive CV AUC (SMOTE): 0.9082 ± 0.0086
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_CatBoost_smote_model.pkl
# 💾 Saved SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_CatBoost_metrics_smote.json
# ⏱️  Runtime for CatBoost: 0.63 minutes
# 🏁 MLflow run for 'CatBoost' closed cleanly.
#
# 🔹 Running SVC...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Re-training best SVC with probability=True for calibrated AUROC...
#    Performing descriptive StratifiedKFold CV on original training set for SVC...
#    Descriptive CV AUC: 0.6610 ± 0.0074
# 💾 Saved SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_SVC_model.pkl
# ✅ SVC done. Best params: {'clf__C': 1, 'clf__gamma': 'scale', 'clf__kernel': 'rbf', 'clf__shrinking': True}
#    CV ROC-AUC: 0.6636 ± 0.019
#    Holdout ROC-AUC: 0.6881
# 💾 Saved non-SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_SVC_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6872
#    Performing descriptive StratifiedKFold CV on SMOTE training set for SVC...
#    Descriptive CV AUC (SMOTE): 0.8677 ± 0.0118
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_SVC_smote_model.pkl
# 💾 Saved SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_SVC_metrics_smote.json
# ⏱️  Runtime for SVC: 0.90 minutes
# 🏁 MLflow run for 'SVC' closed cleanly.
#
# 🔹 Running MLP...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for MLP...
#    Descriptive CV AUC: 0.6739 ± 0.0164
# 💾 Saved MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_MLP_model.pkl
# ✅ MLP done. Best params: {'clf__activation': 'relu', 'clf__alpha': 0.001, 'clf__early_stopping': True, 'clf__hidden_layer_sizes': (64,), 'clf__learning_rate_init': 0.001, 'clf__n_iter_no_change': 10, 'clf__solver': 'adam'}
#    CV ROC-AUC: 0.6704 ± 0.022
#    Holdout ROC-AUC: 0.6949
# 💾 Saved non-SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_MLP_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6700
#    Performing descriptive StratifiedKFold CV on SMOTE training set for MLP...
#    Descriptive CV AUC (SMOTE): 0.8086 ± 0.0405
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_MLP_smote_model.pkl
# 💾 Saved SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_MLP_metrics_smote.json
# ⏱️  Runtime for MLP: 0.11 minutes
# 🏁 MLflow run for 'MLP' closed cleanly.
#
# 🔹 Running NaiveBayes...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for NaiveBayes...
#    Descriptive CV AUC: 0.6740 ± 0.0132
# 💾 Saved NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_NaiveBayes_model.pkl
# ✅ NaiveBayes done. Best params: {'clf__var_smoothing': 1e-09}
#    CV ROC-AUC: 0.6799 ± 0.020
#    Holdout ROC-AUC: 0.7011
# 💾 Saved non-SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_NaiveBayes_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6819
#    Performing descriptive StratifiedKFold CV on SMOTE training set for NaiveBayes...
#    Descriptive CV AUC (SMOTE): 0.7028 ± 0.0175
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_NaiveBayes_smote_model.pkl
# 💾 Saved SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_NaiveBayes_metrics_smote.json
# ⏱️  Runtime for NaiveBayes: 0.01 minutes
# 🏁 MLflow run for 'NaiveBayes' closed cleanly.
#
# 📌 Evaluating all classifiers on holdout test set using CV-trained pipelines:
# LogisticRegression: Holdout ROC-AUC = 0.7234
# DecisionTree: Holdout ROC-AUC = 0.6349
# RandomForest: Holdout ROC-AUC = 0.7264
# GradientBoosting: Holdout ROC-AUC = 0.7267
# XGB: Holdout ROC-AUC = 0.7289
# LGBM: Holdout ROC-AUC = 0.7260
# CatBoost: Holdout ROC-AUC = 0.7343
# SVC: Holdout ROC-AUC = 0.6881
# MLP: Holdout ROC-AUC = 0.6949
# NaiveBayes: Holdout ROC-AUC = 0.7011
#
# 🏆 Best classifier (no SMOTE) = CatBoost, Holdout ROC-AUC = 0.7343
# 💾 Saved best model (no SMOTE) to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_best_model.pkl
# 🏆 Best SMOTE-trained classifier by holdout AUC = CatBoost, AUC = 0.7248
# 🎯 Final evaluation of best SMOTE-trained classifier = CatBoost, ROC-AUC = 0.7248
# 💾 Saved best SMOTE-trained model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_best_smote_model.pkl
# 💾 Saved final SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_best_smote_metrics.json
# 💾 Saved full summary including original and SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_full_summary_with_smote.csv
# 💾 Saved full results dict to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_full.pkl
# 💾 Saved all best SMOTE-trained classifiers to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\original_baseline\original_baseline_20251027_0818\original_baseline_20251027_0818_smote_full.pkl
# ⏱️  Total runtime for mode 'original_baseline': 4.34 minutes
#
# ---
#
# 🏁 MLflow run for 'original_baseline' closed cleanly.
# ✅ Summary exported to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\reports\20251026_NEW\20251027\original_baseline_summary.csv
# ✅ Finished model refit for Original Structured dataset.

# %%
# ==================================================
# 🚀 Refit Final Models Using Previously Discovered Best Parameters
# ==================================================
import os
from src.models import (
    get_classifiers,
    repeated_cv_with_mixed_search,
    auc_scorer
)
from src.utils import resolve_path

# --------------------------------------------------
# 1️⃣  Define best parameters from your 20251025_0258 run
# --------------------------------------------------
# ==================================================
# ✅ Corrected param_spaces_fixed for single-iteration refit
# ==================================================
param_spaces_fixed = {
    "LogisticRegression": [{
        "clf__C": [0.1],
        "clf__l1_ratio": [0.5],
        "clf__max_iter": [1000],
        "clf__penalty": ["elasticnet"],
        "clf__solver": ["saga"]
    }],
    "DecisionTree": [{
        "clf__criterion": ["entropy"],
        "clf__max_depth": [5],
        "clf__min_samples_leaf": [10],
        "clf__min_samples_split": [2]
    }],
    "RandomForest": [{
        "clf__bootstrap": [False],
        "clf__max_depth": [10],
        "clf__max_features": ["sqrt"],
        "clf__min_samples_leaf": [4],
        "clf__min_samples_split": [10],
        "clf__n_estimators": [356]
    }],
    "GradientBoosting": [{
        "clf__learning_rate": [0.019393987736667576],
        "clf__max_depth": [5],
        "clf__max_features": ["log2"],
        "clf__min_samples_leaf": [4],
        "clf__min_samples_split": [3],
        "clf__n_estimators": [301],
        "clf__subsample": [0.9684482051282945]
    }],
    "XGB": [{
        "clf__colsample_bytree": [0.9454044297767479],
        "clf__gamma": [0.4303652916281717],
        "clf__learning_rate": [0.01208563915935721],
        "clf__max_depth": [10],
        "clf__min_child_weight": [3],
        "clf__n_estimators": [848],
        "clf__subsample": [0.8454489914076949]
    }],
    "LGBM": [{
        "clf__colsample_bytree": [0.7880464524154114],
        "clf__learning_rate": [0.014223946814525337],
        "clf__max_depth": [20],
        "clf__min_child_samples": [90],
        "clf__n_estimators": [591],
        "clf__num_leaves": [193],
        "clf__subsample": [0.9370526621593617]
    }],
    "CatBoost": [{
        "clf__depth": [7],
        "clf__iterations": [654],
        "clf__l2_leaf_reg": [8],
        "clf__learning_rate": [0.02031655633456552]
    }],
    "SVC": [{
        "clf__C": [10],
        "clf__gamma": ["scale"],
        "clf__kernel": ["linear"],
        "clf__shrinking": [False]
    }],
    "MLP": [{
        "clf__activation": ["relu"],
        "clf__alpha": [0.0001],
        "clf__early_stopping": [True],
        "clf__hidden_layer_sizes": [(64,)],
        "clf__learning_rate_init": [0.001],
        "clf__n_iter_no_change": [10],
        "clf__solver": ["adam"]
    }],
    "NaiveBayes": [{
        "clf__var_smoothing": [1e-9]
    }]
}


# --------------------------------------------------
# 2️⃣  Prepare minimal refit configuration
# --------------------------------------------------
n_iter_random_per_clf_fixed = {k: 1 for k in param_spaces_fixed.keys()}

# Note: using existing datasets from memory
# Ensure these variables already loaded:
# X_train_w2v, X_test_w2v, y_train_w2v, y_test_w2v,
# X_train_smote_w2v, y_train_smote_w2v

# --------------------------------------------------
# 3️⃣  Run lightweight refit
# --------------------------------------------------
results_refit, summary_refit = repeated_cv_with_mixed_search(
    X_train_w2v, y_train_w2v, X_test_w2v, y_test_w2v,
    classifiers=get_classifiers(),
    param_spaces=param_spaces_fixed,
    X_train_smote=X_train_smote_w2v,
    y_train_smote=y_train_smote_w2v,
    n_splits=5,
    n_repeats=10,
    scoring=auc_scorer,
    n_iter_random=1,
    n_iter_random_per_clf=n_iter_random_per_clf_fixed,
    descriptive_cv=True,
    save_prefix="results/models/w2v_radiology_baseline/",
    mode="w2v_radiology_baseline",
    log_mlflow=True
)

print("✅ Refit complete — all models retrained with fixed parameters.")

export_summary(summary_w2v, save_prefix="reports/20251026_NEW", mode="w2v_radiology_baseline")
print("✅ Finished model training for Radiology Word2Vec dataset.")
# Out:
# ✅ MLflow tracking initialized under unified experiment 'Thesis_ModelTraining'
# Tracking URI: file:///C:/Users/tyler/OneDrive%20-%20University%20of%20Pittsburgh/BIOST%202021%20Thesis/Masters-Thesis/mlflow_tracking (Experiment ID: 169692831354922862)
#
# 🔹 Running LogisticRegression...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for LogisticRegression...
#    Descriptive CV AUC: 0.7345 ± 0.0161
# 💾 Saved LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LogisticRegression_model.pkl
# ✅ LogisticRegression done. Best params: {'clf__C': 0.1, 'clf__l1_ratio': 0.5, 'clf__max_iter': 1000, 'clf__penalty': 'elasticnet', 'clf__solver': 'saga'}
#    CV ROC-AUC: 0.7359 ± 0.017
#    Holdout ROC-AUC: 0.7523
# 💾 Saved non-SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LogisticRegression_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7476
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LogisticRegression...
#    Descriptive CV AUC (SMOTE): 0.7787 ± 0.0127
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LogisticRegression model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LogisticRegression_smote_model.pkl
# 💾 Saved SMOTE metrics for LogisticRegression to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LogisticRegression_metrics_smote.json
# ⏱️  Runtime for LogisticRegression: 0.35 minutes
# 🏁 MLflow run for 'LogisticRegression' closed cleanly.
#
# 🔹 Running DecisionTree...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for DecisionTree...
#    Descriptive CV AUC: 0.6297 ± 0.0215
# 💾 Saved DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_DecisionTree_model.pkl
# ✅ DecisionTree done. Best params: {'clf__criterion': 'entropy', 'clf__max_depth': 5, 'clf__min_samples_leaf': 10, 'clf__min_samples_split': 2}
#    CV ROC-AUC: 0.6303 ± 0.024
#    Holdout ROC-AUC: 0.5977
# 💾 Saved non-SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_DecisionTree_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6361
#    Performing descriptive StratifiedKFold CV on SMOTE training set for DecisionTree...
#    Descriptive CV AUC (SMOTE): 0.7779 ± 0.0104
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained DecisionTree model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_DecisionTree_smote_model.pkl
# 💾 Saved SMOTE metrics for DecisionTree to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_DecisionTree_metrics_smote.json
# ⏱️  Runtime for DecisionTree: 0.10 minutes
# 🏁 MLflow run for 'DecisionTree' closed cleanly.
#
# 🔹 Running RandomForest...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for RandomForest...
#    Descriptive CV AUC: 0.7316 ± 0.0162
# 💾 Saved RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_RandomForest_model.pkl
# ✅ RandomForest done. Best params: {'clf__n_estimators': 356, 'clf__min_samples_split': 10, 'clf__min_samples_leaf': 4, 'clf__max_features': 'sqrt', 'clf__max_depth': 10, 'clf__bootstrap': False}
#    CV ROC-AUC: 0.7280 ± 0.020
#    Holdout ROC-AUC: 0.7325
# 💾 Saved non-SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_RandomForest_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7133
#    Performing descriptive StratifiedKFold CV on SMOTE training set for RandomForest...
#    Descriptive CV AUC (SMOTE): 0.9312 ± 0.0108
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained RandomForest model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_RandomForest_smote_model.pkl
# 💾 Saved SMOTE metrics for RandomForest to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_RandomForest_metrics_smote.json
# ⏱️  Runtime for RandomForest: 3.09 minutes
# 🏁 MLflow run for 'RandomForest' closed cleanly.
#
# 🔹 Running GradientBoosting...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for GradientBoosting...
#    Descriptive CV AUC: 0.7391 ± 0.0135
# 💾 Saved GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_GradientBoosting_model.pkl
# ✅ GradientBoosting done. Best params: {'clf__subsample': 0.9684482051282945, 'clf__n_estimators': 301, 'clf__min_samples_split': 3, 'clf__min_samples_leaf': 4, 'clf__max_features': 'log2', 'clf__max_depth': 5, 'clf__learning_rate': 0.019393987736667576}
#    CV ROC-AUC: 0.7381 ± 0.017
#    Holdout ROC-AUC: 0.7534
# 💾 Saved non-SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_GradientBoosting_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7213
#    Performing descriptive StratifiedKFold CV on SMOTE training set for GradientBoosting...
#    Descriptive CV AUC (SMOTE): 0.9167 ± 0.0102
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained GradientBoosting model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_GradientBoosting_smote_model.pkl
# 💾 Saved SMOTE metrics for GradientBoosting to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_GradientBoosting_metrics_smote.json
# ⏱️  Runtime for GradientBoosting: 1.06 minutes
# 🏁 MLflow run for 'GradientBoosting' closed cleanly.
#
# 🔹 Running XGB...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:12] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Performing descriptive StratifiedKFold CV on original training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:22] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:31] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:39] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:49] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:47:58] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC: 0.7480 ± 0.0160
# 💾 Saved XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_XGB_model.pkl
# ✅ XGB done. Best params: {'clf__subsample': 0.8454489914076949, 'clf__n_estimators': 848, 'clf__min_child_weight': 3, 'clf__max_depth': 10, 'clf__learning_rate': 0.01208563915935721, 'clf__gamma': 0.4303652916281717, 'clf__colsample_bytree': 0.9454044297767479}
#    CV ROC-AUC: 0.7435 ± 0.017
#    Holdout ROC-AUC: 0.7522
# 💾 Saved non-SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_XGB_metrics_non_smote.json
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:48:07] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    SMOTE Holdout ROC-AUC: 0.7420
#    Performing descriptive StratifiedKFold CV on SMOTE training set for XGB...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:48:19] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:48:31] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:48:43] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:48:54] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\xgboost\training.py:183: UserWarning: [13:49:06] WARNING: C:\b\abs_d97hy_84m6\croot\xgboost-split_1749630932152\work\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#    Descriptive CV AUC (SMOTE): 0.9533 ± 0.0048
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained XGB model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_XGB_smote_model.pkl
# 💾 Saved SMOTE metrics for XGB to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_XGB_metrics_smote.json
# ⏱️  Runtime for XGB: 6.45 minutes
# 🏁 MLflow run for 'XGB' closed cleanly.
#
# 🔹 Running LGBM...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for LGBM...
#    Descriptive CV AUC: 0.7476 ± 0.0167
# 💾 Saved LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LGBM_model.pkl
# ✅ LGBM done. Best params: {'clf__subsample': 0.9370526621593617, 'clf__num_leaves': 193, 'clf__n_estimators': 591, 'clf__min_child_samples': 90, 'clf__max_depth': 20, 'clf__learning_rate': 0.014223946814525337, 'clf__colsample_bytree': 0.7880464524154114}
#    CV ROC-AUC: 0.7429 ± 0.018
#    Holdout ROC-AUC: 0.7499
# 💾 Saved non-SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LGBM_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7371
#    Performing descriptive StratifiedKFold CV on SMOTE training set for LGBM...
#    Descriptive CV AUC (SMOTE): 0.9458 ± 0.0060
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained LGBM model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LGBM_smote_model.pkl
# 💾 Saved SMOTE metrics for LGBM to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_LGBM_metrics_smote.json
# ⏱️  Runtime for LGBM: 1.01 minutes
# 🏁 MLflow run for 'LGBM' closed cleanly.
#
# 🔹 Running CatBoost...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for CatBoost...
#    Descriptive CV AUC: 0.7431 ± 0.0128
# 💾 Saved CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_CatBoost_model.pkl
# ✅ CatBoost done. Best params: {'clf__learning_rate': 0.02031655633456552, 'clf__l2_leaf_reg': 8, 'clf__iterations': 654, 'clf__depth': 7}
#    CV ROC-AUC: 0.7438 ± 0.018
#    Holdout ROC-AUC: 0.7568
# 💾 Saved non-SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_CatBoost_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7412
#    Performing descriptive StratifiedKFold CV on SMOTE training set for CatBoost...
#    Descriptive CV AUC (SMOTE): 0.9409 ± 0.0080
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained CatBoost model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_CatBoost_smote_model.pkl
# 💾 Saved SMOTE metrics for CatBoost to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_CatBoost_metrics_smote.json
# ⏱️  Runtime for CatBoost: 7.92 minutes
# 🏁 MLflow run for 'CatBoost' closed cleanly.
#
# 🔹 Running SVC...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Re-training best SVC with probability=True for calibrated AUROC...
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# C:\Users\tyler\anaconda3\envs\Masters-Thesis\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
#    Performing descriptive StratifiedKFold CV on original training set for SVC...
#    Descriptive CV AUC: 0.7098 ± 0.0086
# 💾 Saved SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_SVC_model.pkl
# ✅ SVC done. Best params: {'clf__C': 10, 'clf__gamma': 'scale', 'clf__kernel': 'linear', 'clf__shrinking': False}
#    CV ROC-AUC: 0.7108 ± 0.017
#    Holdout ROC-AUC: 0.731
# 💾 Saved non-SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_SVC_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7338
#    Performing descriptive StratifiedKFold CV on SMOTE training set for SVC...
#    Descriptive CV AUC (SMOTE): 0.7750 ± 0.0128
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained SVC model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_SVC_smote_model.pkl
# 💾 Saved SMOTE metrics for SVC to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_SVC_metrics_smote.json
# ⏱️  Runtime for SVC: 657.61 minutes
# 🏁 MLflow run for 'SVC' closed cleanly.
#
# 🔹 Running MLP...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for MLP...
#    Descriptive CV AUC: 0.7267 ± 0.0115
# 💾 Saved MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_MLP_model.pkl
# ✅ MLP done. Best params: {'clf__activation': 'relu', 'clf__alpha': 0.0001, 'clf__early_stopping': True, 'clf__hidden_layer_sizes': (64,), 'clf__learning_rate_init': 0.001, 'clf__n_iter_no_change': 10, 'clf__solver': 'adam'}
#    CV ROC-AUC: 0.7142 ± 0.026
#    Holdout ROC-AUC: 0.7352
# 💾 Saved non-SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_MLP_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.7059
#    Performing descriptive StratifiedKFold CV on SMOTE training set for MLP...
#    Descriptive CV AUC (SMOTE): 0.9034 ± 0.0093
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained MLP model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_MLP_smote_model.pkl
# 💾 Saved SMOTE metrics for MLP to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_MLP_metrics_smote.json
# ⏱️  Runtime for MLP: 0.32 minutes
# 🏁 MLflow run for 'MLP' closed cleanly.
#
# 🔹 Running NaiveBayes...
# Fitting 50 folds for each of 1 candidates, totalling 50 fits
#    Performing descriptive StratifiedKFold CV on original training set for NaiveBayes...
#    Descriptive CV AUC: 0.6634 ± 0.0200
# 💾 Saved NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_NaiveBayes_model.pkl
# ✅ NaiveBayes done. Best params: {'clf__var_smoothing': 1e-09}
#    CV ROC-AUC: 0.6643 ± 0.018
#    Holdout ROC-AUC: 0.6732
# 💾 Saved non-SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_NaiveBayes_metrics_non_smote.json
#    SMOTE Holdout ROC-AUC: 0.6491
#    Performing descriptive StratifiedKFold CV on SMOTE training set for NaiveBayes...
#    Descriptive CV AUC (SMOTE): 0.7222 ± 0.0133
#    (5 valid folds out of 5)
# 💾 Saved SMOTE-trained NaiveBayes model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_NaiveBayes_smote_model.pkl
# 💾 Saved SMOTE metrics for NaiveBayes to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_NaiveBayes_metrics_smote.json
# ⏱️  Runtime for NaiveBayes: 0.01 minutes
# 🏁 MLflow run for 'NaiveBayes' closed cleanly.
#
# 📌 Evaluating all classifiers on holdout test set using CV-trained pipelines:
# LogisticRegression: Holdout ROC-AUC = 0.7523
# DecisionTree: Holdout ROC-AUC = 0.5977
# RandomForest: Holdout ROC-AUC = 0.7325
# GradientBoosting: Holdout ROC-AUC = 0.7534
# XGB: Holdout ROC-AUC = 0.7522
# LGBM: Holdout ROC-AUC = 0.7499
# CatBoost: Holdout ROC-AUC = 0.7568
# SVC: Holdout ROC-AUC = 0.7310
# MLP: Holdout ROC-AUC = 0.7352
# NaiveBayes: Holdout ROC-AUC = 0.6732
#
# 🏆 Best classifier (no SMOTE) = CatBoost, Holdout ROC-AUC = 0.7568
# 💾 Saved best model (no SMOTE) to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_best_model.pkl
# 🏆 Best SMOTE-trained classifier by holdout AUC = LogisticRegression, AUC = 0.7476
# 🎯 Final evaluation of best SMOTE-trained classifier = LogisticRegression, ROC-AUC = 0.7476
# 💾 Saved best SMOTE-trained model to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_best_smote_model.pkl
# 💾 Saved final SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_best_smote_metrics.json
# 💾 Saved full summary including original and SMOTE metrics to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_full_summary_with_smote.csv
# 💾 Saved full results dict to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_full.pkl
# 💾 Saved all best SMOTE-trained classifiers to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\models\w2v_radiology_baseline\w2v_radiology_baseline_20251026_1338\w2v_radiology_baseline_20251026_1338_smote_full.pkl
# ⏱️  Total runtime for mode 'w2v_radiology_baseline': 677.97 minutes
#
# ---
#
# 🏁 MLflow run for 'w2v_radiology_baseline' closed cleanly.
# ✅ Refit complete — all models retrained with fixed parameters.
# ✅ Summary exported to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\reports\20251026_NEW\20251027\w2v_radiology_baseline_summary.csv
# ✅ Finished model training for Radiology Word2Vec dataset.

# %%
# ==================================================
# 📊 Merge and Export Refit Comparison Summaries
# ==================================================
import os
import pandas as pd
from src.utils import resolve_path

# --- Tag refit summaries for clarity ---
summary_orig_refit["Dataset"] = "original"
summary_refit["Dataset"] = "w2v_radiology"

# Optional: include discharge/combined refit summaries if available
if "summary_w2v_dis_refit" in globals():
    summary_w2v_dis_refit["Dataset"] = "w2v_discharge"

if "summary_w2v_comb_refit" in globals():
    summary_w2v_comb_refit["Dataset"] = "w2v_combined"

# --- Merge all available refit summaries ---
all_refit_summaries = [summary_orig_refit, summary_refit]

if "summary_w2v_dis_refit" in globals():
    all_refit_summaries.append(summary_w2v_dis_refit)

if "summary_w2v_comb_refit" in globals():
    all_refit_summaries.append(summary_w2v_comb_refit)

refit_comparison = pd.concat(all_refit_summaries, axis=0, ignore_index=True)

# --- Save merged refit comparison summary ---
refit_summary_path = resolve_path("results/reports/20251027baseline_comparison.csv")
os.makedirs(os.path.dirname(refit_summary_path), exist_ok=True)
refit_comparison.to_csv(refit_summary_path, index=False)
print(f"💾 Saved merged refit comparison summary to {refit_summary_path}")

# --- Optional: Log to MLflow ---
if "mlflow" in globals():
    try:
        mlflow.log_artifact(refit_summary_path, artifact_path="summaries")
        print("📤 Logged refit comparison summary to MLflow under 'summaries/'")
    except Exception as e:
        print(f"⚠️ MLflow logging skipped ({e})")

# --- Display tidy summary table ---
cols_to_display = [
    "Dataset",
    "Classifier",
    "Holdout ROC-AUC",
    "Holdout Precision",
    "Holdout Recall",
    "Holdout F1",
    "Holdout ROC-AUC (SMOTE)",
    "Final Holdout ROC-AUC (SMOTE)",
]

display_cols = [c for c in cols_to_display if c in refit_comparison.columns]
display(refit_comparison[display_cols].sort_values(by=["Dataset", "Holdout ROC-AUC"], ascending=[True, False]))
# Out:
# 💾 Saved merged refit comparison summary to C:\Users\tyler\OneDrive - University of Pittsburgh\BIOST 2021 Thesis\Masters-Thesis\results\reports\20251027baseline_comparison.csv
#           Dataset          Classifier  Holdout ROC-AUC  Holdout Precision  \
# 0        original            CatBoost         0.734284           0.545455
# 1        original                 XGB         0.728923           0.535714
# 2        original    GradientBoosting         0.726701           0.551020
# 3        original        RandomForest         0.726405           0.916667
# 4        original                LGBM         0.725975           0.482759
# 5        original  LogisticRegression         0.723406           0.483333
# 6        original          NaiveBayes         0.701084           0.406844
# 7        original                 MLP         0.694930           0.433333
# 8        original                 SVC         0.688066           0.777778
# 9        original        DecisionTree         0.634860           0.516667
# 10  w2v_radiology            CatBoost         0.756803           0.561404
# 11  w2v_radiology    GradientBoosting         0.753368           0.551020
# 12  w2v_radiology  LogisticRegression         0.752343           0.586667
# 13  w2v_radiology                 XGB         0.752203           0.532258
# 14  w2v_radiology                LGBM         0.749913           0.565217
# 15  w2v_radiology                 MLP         0.735248           0.522727
# 16  w2v_radiology        RandomForest         0.732508           0.875000
# 17  w2v_radiology                 SVC         0.731005           0.000000
# 18  w2v_radiology          NaiveBayes         0.673220           0.333333
# 19  w2v_radiology        DecisionTree         0.597655           0.357143
#
#     Holdout Recall  Holdout F1  Holdout ROC-AUC (SMOTE)  \
# 0         0.124481    0.202703                 0.724805
# 1         0.124481    0.202020                 0.712693
# 2         0.112033    0.186207                 0.703203
# 3         0.045643    0.086957                 0.702074
# 4         0.174274    0.256098                 0.709917
# 5         0.120332    0.192691                 0.716185
# 6         0.443983    0.424603                 0.681948
# 7         0.107884    0.172757                 0.669951
# 8         0.029046    0.056000                 0.687227
# 9         0.128631    0.205980                 0.629568
# 10        0.132780    0.214765                 0.741247
# 11        0.112033    0.186207                 0.721349
# 12        0.182573    0.278481                 0.747577
# 13        0.136929    0.217822                 0.741951
# 14        0.161826    0.251613                 0.737128
# 15        0.190871    0.279635                 0.705897
# 16        0.029046    0.056225                 0.713325
# 17        0.000000    0.000000                 0.733823
# 18        0.630705    0.436155                 0.649106
# 19        0.062241    0.106007                 0.636051
#
#    Final Holdout ROC-AUC (SMOTE)
# 0                       0.724805
# 1                           None
# 2                           None
# 3                           None
# 4                           None
# 5                           None
# 6                           None
# 7                           None
# 8                           None
# 9                           None
# 10                          None
# 11                          None
# 12                      0.747577
# 13                          None
# 14                          None
# 15                          None
# 16                          None
# 17                          None
# 18                          None
# 19                          None
