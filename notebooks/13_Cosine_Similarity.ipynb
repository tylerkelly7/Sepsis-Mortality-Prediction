# %% [markdown]
# ## 1 Load and Print Parameters

# %%
from gensim.models import Word2Vec
from src.utils import resolve_path

model_path = resolve_path("embedding_cache/w2v/variants/Radiology/best_Radiology.model")
w2v = Word2Vec.load(str(model_path))

# Print key training parameters
print("Word2Vec Model Parameters:")
print("----------------------------------")
print(f"vector_size:        {w2v.vector_size}")
print(f"window:             {w2v.window}")
print(f"min_count:          {w2v.min_count}")
print(f"workers:            {w2v.workers}")
print(f"sg (skip-gram=1):   {w2v.sg}")
print(f"hs (hierarchical):  {w2v.hs}")
print(f"negative sampling:  {w2v.negative}")
print(f"epochs:             {w2v.epochs}")
print(f"sample:             {w2v.sample}")
print(f"alpha:              {w2v.alpha}")
print(f"min_alpha:          {w2v.min_alpha}")
print(f"cbow_mean:          {w2v.cbow_mean}")
print(f"total_words:        {w2v.corpus_total_words}")
print(f"total_examples:     {w2v.corpus_count}")
# Out:
# Word2Vec Model Parameters:
# ----------------------------------
# vector_size:        100
# window:             10
# min_count:          2
# workers:            12
# sg (skip-gram=1):   1
# hs (hierarchical):  0
# negative sampling:  10
# epochs:             15
# sample:             0.001
# alpha:              0.025
# min_alpha:          0.0001
# cbow_mean:          1
# total_words:        45728312
# total_examples:     5206

# %% [markdown]
# ## Define a helper to embed whole documents

# %%
import numpy as np

def embed_document(text, w2v_model):
    tokens = text.lower().split()
    vectors = [w2v_model.wv[w] for w in tokens if w in w2v_model.wv]
    if len(vectors) == 0:
        return np.zeros(w2v_model.vector_size)
    return np.mean(vectors, axis=0)

# %% [markdown]
# ## 3 Cosine similarity function

# %%
from numpy.linalg import norm

def cosine_sim(a, b):
    if norm(a) == 0 or norm(b) == 0:
        return 0.0
    return np.dot(a, b) / (norm(a) * norm(b))

# %% [markdown]
# ## 4 Get any two patients’ radiology notes

# %%
import pandas as pd

df = pd.read_csv(resolve_path("data/interim/data_full_notes_interim.csv"))
df_full = pd.read_csv(resolve_path("data/interim/data_nlp_ready.csv"))

# %%
df['note_type_1'].values
# Out:
# array(['radiology', 'radiology', 'radiology', ..., 'discharge',
#        'discharge', 'discharge'], dtype=object)

# %%
def get_patient_note(df, subject_id):
    row = df.loc[
        (df['subject_id'] == subject_id) & 
        (df['note_type_1'].str.lower() == 'radiology')
    ]
    
    if row.empty:
        return None
    
    return row['text'].values[0]

# %%
def get_patient_note_full(df_full, subject_id):
    row = df_full.loc[
        (df_full['subject_id'] == subject_id)
    ]
    
    if row.empty:
        return None
    
    return row['Radiology_notes'].values[0]

# %%
# Example
note_1 = get_patient_note(df, 14923562)
print(note_1)
# Out:
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with s/p liver transplant with prolonged course,
# currently trached with MDR E coli PNA, increasing O2 requirements recently//
# ?interval change     ?interval change
#
# IMPRESSION:
#
# Compared to chest radiographs ___ through ___ one at 23:48.
#
# Moderate pulmonary edema seen best in the right lung has worsened.  There is
# substantial new right basal consolidation, and increase in left perihilar
# consolidation, either combinations of edema and atelectasis or pneumonia.
# Cardiac silhouette is partially obscured but moderate cardiomegaly appears to
# have increased.
#
# Tracheostomy tube in standard placement.  Left dual channel dialysis catheters
# end in the SVC and close to the superior cavoatrial junction.  Right jugular
# line ends at the thoracic inlet, all unchanged.
#
# There may be new fluid in the previously air containing externalized right
# pleural space, a function of cardiac decompensation.

# %%
note_1_full = get_patient_note_full(df_full, 14923562)
print(note_1_full)
# Out:
# EXAMINATION: CHEST (PORTABLE AP) INDICATION:  year old man with sp liver transplant with prolonged course, currently trached with MDR E coli PNA, increasing O2 requirements recently ?interval change ?interval change IMPRESSION: Compared to chest radiographs  through  one at 23:48. Moderate pulmonary edema seen best in the right lung has worsened. There is substantial new right basal consolidation, and increase in left perihilar consolidation, either combinations of edema and atelectasis or pneumonia. Cardiac silhouette is partially obscured but moderate cardiomegaly appears to have increased. Tracheostomy tube in standard placement. Left dual channel dialysis catheters end in the SVC and close to the superior cavoatrial junction. Right jugular line ends at the thoracic inlet, all unchanged. There may be new fluid in the previously air containing externalized right pleural space, a function of cardiac decompensation. EXAMINATION: CHEST (PORTABLE AP) INDICATION:  year old man with LLL consolidation and sepsis Interval changes COMPARISON: Chest radiographs from  through  Chest CT dated  FINDINGS: AP portable view of the chest provided. Compared to the  study, lung volumes are slightly increased. Moderate pulmonary edema has improved. The left basilar and perihilar consolidation is less confluent, although persistent. The cardiac silhouette is again partially obscured, but mild cardiomegaly is likely stable allowing for the AP projection and previously low lung volumes. The externalized right pleural space is unchanged. There is no pneumothorax. Cardiopulmonary support lines and tubes are in unchanged position. IMPRESSION: 1. Pulmonary edema has improved and is now mild. 2. Persistent left lower lobe consolidation concerning for pneumonia. 3. Mild cardiomegaly. EXAMINATION: ABDOMEN US (COMPLETE STUDY) INDICATION:  year old man with alcoholic cirrhosis, worsening jaundice, pruritus, and hepatorenal syndrome. (note: also has history of cholecystectomy), evaluate for portal vein thrombosis given worsening jaundice. Also has HRS, so please evaluate kidneys too. TECHNIQUE: Gray scale, color, and spectral Doppler evaluation of the abdomen was performed. COMPARISON: None available. FINDINGS: Liver: The hepatic parenchyma is coarsened and nodular.. No focal liver lesions are identified. There is small volume perihepatic ascites. Bile ducts: There is no intrahepatic biliary ductal dilation. The common hepatic duct measures 3 mm. Gallbladder: The gallbladder was not visualized. Pancreas: The imaged portion of the pancreas appears within normal limits, with portions of the pancreatic tail obscured by overlying bowel gas. Spleen: The spleen demonstrates normal echotexture, and measures 16.4 cm. Kidneys: The right kidney measures 11.5 cm. The left kidney measures 11.3 cm. No stones, masses, or hydronephrosis are identified in either kidney. Doppler evaluation: The main portal vein is notable for lack of demonstrable internal flow, which could be due to thrombosis or slow (undetectable) flow.. Main portal vein velocity is not detectable. Right and left portal veins are notable for lack of demonstrable internal flow. The main hepatic artery is patent, with appropriate waveform. Right, middle and left hepatic veins are patent, with appropriate waveforms. Splenic vein and superior mesenteric vein are not visualized. IMPRESSION: 1. Flow within the main, right, and left portal veins is not detectable, highly concerning for portal thrombus. CT or MR could be obtained for further evaluation if clinically indicated. 2. Cirrhotic liver with marked splenomegaly and trace perihepatic ascites. No suspicious liver lesion is detected. 3. Normal appearance of the kidneys. NOTIFICATION: The findings were discussed with , M.D. by , M.D. on the telephone on  at 11:21 AM, 5 minutes after discovery of the findings. EXAMINATION: DUPLEX DOPP ABDPEL PORT INDICATION: transplant vasculature TECHNIQUE: Gray scale, color, and spectral Doppler evaluation of the abdomen wa ...

# %%
note_2 = get_patient_note(df, 11619087)
print(note_2)
# Out:
# INDICATION:  ___ year old woman with UTI, likely drug resistant, great
# difficulty with peripheral venous access.// picc placement
#
# COMPARISON:  ___
#
# TECHNIQUE:  OPERATORS: Dr. ___ and Dr.
# ___ radiologist performed the procedure. Dr. ___
# ___ supervised the trainee during the key components of the procedure
# and has reviewed and agrees with the trainee's findings.
# ANESTHESIA: 1% lidocaine was injected in the skin and subcutaneous tissues
# overlying the access site.
# CONTRAST: 5 ml of Optiray contrast.
# FLUOROSCOPY TIME AND DOSE: 3.54 min, 16.8 mGy
#
# PROCEDURE:
# 1. Double lumen PICC placement through the right brachial vein.
#
# PROCEDURE DETAILS: Using sterile technique and local anesthesia, the right
# brachial vein was punctured under direct ultrasound guidance using a
# micropuncture set. Permanent ultrasound images were obtained before and after
# intravenous access, which confirmed vein patency.  The guidewire could not be
# advanced easily.  The inner of a micropuncture sheath was advanced over the
# wire.  The wire was removed and a venogram was performed.  The wire was placed
# again and then into the SVC.  A peel-away sheath was then placed over a
# guidewire.  A double lumen PIC line measuring 39 cm in length was then placed
# through the peel-away sheath with its tip positioned in the distal SVC under
# fluoroscopic guidance. Position of the catheter was confirmed by a
# fluoroscopic spot film of the chest. The peel-away sheath and guidewire were
# then removed. The catheter was secured to the skin, flushed, and a sterile
# dressing applied.
# The patient tolerated the procedure well. There were no immediate
# complications.
#
# FINDINGS:
#
# 1.  The accessed vein was patent and compressible.
# 2.  Right brachial venogram demonstrates patent brachial and axillary veins.
# 2.  Brachialvein approach double lumen right PICC with tip in the distal SVC.
#
# IMPRESSION:
#
# Successful placement of a right 39 cm brachial approach double lumen PowerPICC
# with tip in the distal SVC.  The line is ready to use.
#
# Of note, similar to the prior PICC placement in the right arm, there was
# difficulty advancing the PICC past the right brachiocephalic vein indicating
# likely central venous stenosis.

# %% [markdown]
# ## 5 Compare Cosine Similarity

# %%
# Example above
vec_1 = embed_document(note_1, w2v)
vec_2 = embed_document(note_2, w2v)

similarity = cosine_sim(vec_1, vec_2)
similarity
# Out:
# 0.7661022

# %% [markdown]
# ## 6 Get 50 Random Similarity Scores

# %%
import itertools

patient_ids = df['subject_id'].unique()[:200]  # sample for speed

results = []
for a, b in itertools.combinations(patient_ids, 2):
    note_a = get_patient_note(df, a)
    note_b = get_patient_note(df, b)
    sim = cosine_sim(
        embed_document(note_a, w2v),
        embed_document(note_b, w2v)
    )
    results.append((a, b, sim))

# Sort descending
results_sorted = sorted(results, key=lambda x: x[2], reverse=True)
results_sorted[:5]
# Out:
# [(18486555, 14788557, 0.9972115),
#  (12214410, 14788557, 0.9971013),
#  (18486555, 12214410, 0.9961083),
#  (12542700, 12683473, 0.9923077),
#  (10804922, 14788557, 0.9915437)]

# %%
results_sorted_low = sorted(results, key=lambda x: x[2])
results_sorted_low[:5]
# Out:
# [(17978114, 11863401, 0.55611366),
#  (15552419, 11863401, 0.5781456),
#  (12468016, 11863401, 0.5928373),
#  (11619087, 11863401, 0.5985415),
#  (17978114, 14174955, 0.6112414)]

# %% [markdown]
# ### High Cosine Similarity

# %%
#(18486555, 12214410, 0.9961083)

note_A = get_patient_note(df, 18486555)
note_B = get_patient_note(df, 12214410)

vec_A = embed_document(note_A, w2v)
vec_B = embed_document(note_B, w2v)

similarity1 = cosine_sim(vec_A, vec_B)
similarity1
# Out:
# 0.9961083

# %%
print(note_A)
# Out:
# EXAMINATION:  BILAT LOWER EXT VEINS
#
# INDICATION:  ___ year old man with leg weakness and calf tenderness.  // ? DVT
#
# TECHNIQUE:  Grey scale, color, and spectral Doppler evaluation was performed
# on the bilateral lower extremity veins.
#
# COMPARISON:  None.
#
# FINDINGS:
#
# There is normal compressibility, flow, and augmentation of the bilateral
# common femoral, femoral, and popliteal veins. Normal color flow and
# compressibility are demonstrated in the posterior tibial and peroneal veins.
#
# There is normal respiratory variation in the common femoral veins bilaterally.
#
# No evidence of medial popliteal fossa (___) cyst.
#
# IMPRESSION:
#
# No evidence of deep venous thrombosis in the right or left lower extremity
# veins.

# %%
print(note_B)
# Out:
# EXAMINATION:  UNILAT LOWER EXT VEINS RIGHT
#
# INDICATION:  ___ with R leg swelling.  DVT?
#
# TECHNIQUE:  Grey scale, color, and spectral Doppler evaluation was performed
# on the right lower extremity veins.
#
# COMPARISON:  None.
#
# FINDINGS:
#
# There is normal compressibility, flow, and augmentation of the right common
# femoral, femoral, and popliteal veins. Normal color flow and compressibility
# are demonstrated in the tibial and peroneal veins.
#
# There is normal respiratory variation in the common femoral veins bilaterally.
#
# No evidence of medial popliteal fossa (___) cyst.
#
# IMPRESSION:
#
# No evidence of deep venous thrombosis in the right lower extremity veins.

# %% [markdown]
# ### Low Cosine Similarity

# %%
#(17978114, 11863401, 0.55611366)

note_C = get_patient_note(df, 17978114)
note_D = get_patient_note(df, 11863401)

vec_C = embed_document(note_C, w2v)
vec_D = embed_document(note_D, w2v)

similarity2 = cosine_sim(vec_C, vec_D)
similarity2
# Out:
# 0.55611366

# %%
print(note_C)
# Out:
# TRANSJUGULAR LIVER BIOPSY
#
# INDICATION:  ___ woman with liver dysfunction, elevated INR.
#
# OPERATORS:  Drs. ___ (fellow), ___ (resident) and ___
# ___ (attending physician).  Dr. ___ was present during key moments of the
# procedure.
#
# SEDATION:  Moderate sedation in divided doses of intravenous ___ mcg fentanyl
# and 2.5 mg of Versed over 50 minutes, during which patient's hemodynamic
# status was continuously monitored by a trained radiology nurse.
#
# PROCEDURE AND FINDINGS:  Consent was obtained from the patient after
# explaining the benefits, risks, and alternatives.  The patient was placed
# supine on the imaging table in the interventional suite.  Timeout was
# performed as per ___ protocol.
#
# Under aseptic conditions, sonographic guidance, and after infiltrating the
# skin and subcutaneous tissues with 1% lidocaine, a micropuncture needle was
# placed in the patent right internal jugular vein.  A 0.018 wire was advanced
# through the needle and into the SVC.  After making an incision, needle was
# exchanged for a 4 ___ microsheath.  Inner cannula and wire were removed to
# place a 0.035 ___ wire, which was advanced into the IVC.  After removing the
# microsheath, the tract was dilated under fluoroscopy with a ___ dilator.
# A ___ long ___ sheath was then placed over the wire and advanced
# into the IVC.  After removing the inner cannula, the sidearm was aspirated and
# flushed. A trimmed 5 ___ C2 catheter was placed within the sheath and
# advanced into the IVC.  After retracting the ___ sheath to the right
# atrium, the ___ wire was with a 0.035 angled Glidewire.  Catheter-Glidewire
# combination was then used to access the middle hepatic vein.  The Glidewire
# was then replaced with ___ wire, which was advanced into the middle hepatic
# vein.  The ___ sheath was then advanced into the middle hepatic vein.
# Some sterile contrast material was injected into the catheter to confirm its
# position within the middle hepatic vein (in AP and lateral projections).  The
# C2 catheter was then removed over the ___ wire to place the curved sheath
# metallic cannula (mamba), which was advanced into the middle hepatic vein just
# distal to the outer sheath tip.  After removing the wire, a semi-automatic
# biopsy needle was placed within the metallic cannula to obtain three passes of
# core samples of liver tissue.  After removing the needle and curved metallic
# cannula, the outer sheath was removed over the ___ wire.  Firm pressure was
# applied to the venotomy site for about 15 minutes to achieve complete
# hemostasis.  Site was dressed in a sterile fashion.  Liver tissue samples were
# sent for laboratory analysis.  Patient tolerated the procedure well and no
# immediate post-procedure complication was seen.
#
# IMPRESSION:  Uncomplicated transjugular liver biopsy from the middle hepatic
# vein.  Three cores of liver tissue samples were obtained, which were sent for
# analysis.

# %%
print(note_D)
# Out:
# EXAMINATION:  CHEST (PORTABLE AP)
#
# INDICATION:  ___ year old man with alcoholic hepatitis, w/mild hypoxia and
# sob// consolidation, pleural effusion, pulm edema      consolidation, pleural
# effusion, pulm edema
#
# IMPRESSION:
#
# Heart size and mediastinum are overall normal in size.  Left retrocardiac
# consolidation might be consistent with hernia versus varices versus infectious
# process.  Lung volumes are low.  Bibasal atelectasis is present.  Bilateral
# pleural effusion cannot be excluded.  There is no pulmonary edema.  There is
# no pneumothorax.

# %% [markdown]
# ## Check for Information leakage

# %% [markdown]
# Patient 2 below shows potential information with the word 'death' being included in the text notes due to brain-death protocol.

# %%
died_df = df_full[df_full['hospital_expire_flag'] == 1]

sample_patients = died_df['subject_id'].drop_duplicates().sample(5, random_state=42)
sample_patients

for sid in sample_patients:
    note = died_df.loc[died_df['subject_id'] == sid, 'Radiology_notes'].values[0]
    print(f"SUBJECT ID {sid}:\n{note[:]}\n\n")
# Out:
# SUBJECT ID 10007818:
# EXAMINATION: CT CHEST WCONTRAST INDICATION:  man with cirrhosis and bacteremia with rising leukocytosis. Evaluate for source of infection. TECHNIQUE: Multidetector helical scanning of the chest was coordinated with intravenous infusion of nonionic iodinated contrast agent reconstructed as contiguous 5- and 1.25-mm thick axial, 2.5-mm thick coronal and parasagittal, and 8 x 8 mm MIPs axial images. DOSE: See same-day CTA ABD AND PELVIS for dose report. COMPARISON: Ultrasound , arteriogram , CT , CT . FINDINGS: The thoracic aorta is normal in caliber with minimal atherosclerotic calcifications at the aortic arch. Incidentally noted is a two vessel takeoff from the aortic arch. The pulmonary artery is normal in caliber. Contrast bolus timing is not optimized to evaluate for pulmonary embolism but there is no large central PE. No pathologically enlarged supraclavicular, axillary, mediastinal or hilar lymph nodes are identified ranging up to 8 mm in the right lower paratracheal station. Coronary artery calcifications in the LAD, left circumflex and right coronary artery are of unknown hemodynamic significance. There is no pericardial effusion. No nodules are seen in the thyroid gland. The patient is intubated. A dialysis catheter ends in the right atrium. A nasoenteric tube terminates in the stomach. There are small bilateral pleural effusions with adjacent compressive atelectasis and volume loss in the bilateral lower lobes. There is no worrisome nodule or mass. Central airways are patent. Subdiaphragmatic structures are reported separately. No bone finding suspicious for infection or malignancy is seen. Degenerative change is noted in the thoracic spine. IMPRESSION: 1. Small bilateral pleural effusions with adjacent consolidation, which appears to be predominantly atelectasis. A component of infection may also be present. 2. CT abdomenpelvis reported separately. NOTIFICATION: The findings were discussed by Dr.  with Dr.   on the telephoneon  at 4:14 , 10 minutes after discovery of the findings. EXAMINATION: CHEST (PORTABLE AP) INDICATION:  year old man with hypoxemic respiratory failure, LLL collapse, now with increasing 02 requirement  please assess for interval change please assess for interval change COMPARISON: Prior chest radiographs  through . IMPRESSION: Left lower lobe collapse reflected in severe leftward mediastinal shift, is accompanied by increasing moderate left pleural effusion. Right lung is clear. Heart size indeterminate. Tip of the endotracheal tube is at the upper margin of the clavicles, no less than 6 cm from the carina. Feeding tube passes into the stomach, beyond the esophageal drainage tube, and out of view. Note pneumothorax. Right jugular catheters end in the mid and low SVC. Second right jugular catheter could be a ventricular caval shunt, ending in the upper SVC. INDICATION:  year old man with hypoxemic respiratory failure, ongoing issues with LLL collapse, now sp bronchoscopy.  evaluate for interval change TECHNIQUE: Chest PA and lateral FINDINGS: As compared to chest radiograph from earlier today, left lower lobe collapse and moderate left pleural effusion, unchanged. Right lung is clear. Heart size indeterminate. Tip of the endotracheal tube is at the upper margin of the clavicles, no less than 6 cm from the carina. Feeding tube passes into the stomach, beyond the esophageal drainage tube. No pneumothorax. Right jugular catheters end in the mid and low SVC. IMPRESSION: Persistent left lower lobe collapse and adjacent moderate effusion. EXAMINATION: CTA ABD AND PELVIS INDICATION:  w cirrhosis sp cardiac cath via R groin now w severe hypotension and drop in crit  ? RP bleed TECHNIQUE: Abdomen and pelvis CTA: Non-contrast and arterial phase images were acquired through the abdomen and pelvis. IV Contrast: 150mL of Omnipaque Oral contrast was not administered. MIP reconstructions were performed on independent workstation and reviewed on PACS. DOSE: Total DLP (Body)  1,970 mGy-cm. COMPARISON: MRI abdomen  ...
#
#
# SUBJECT ID 18341422:
# EXAMINATION: Chest radiograph, portable AP upright. INDICATION: Endotracheal intubation. COMPARISON: None available. FINDINGS: Endotracheal tube terminates about 5.5 cm above the carina. An orogastric tube terminates in the stomach. Lung volumes are low. Cardiac, mediastinal and hilar contours appear within normal limits, given technique. There is no pleural effusion or pneumothorax. Patchy opacities at the lung bases, greater on the right than left could be seen with aspiration or pneumonia. Correlation with clinical circumstances and consideration of short-term follow-up radiographs is suggested. Bony structures are unremarkable. IMPRESSION: Status post endotracheal intubation. Orogastric tube terminating in the stomach. It may be appropriate, however, to consider dancing the tube by about 5 cm for better seating. Opacities in each lower lung, more striking on the right than left. EXAMINATION: CHEST (PORTABLE AP) INDICATION:  year old man with intracranial hemorrhage per brain death brotocol Per brain death protocol IMPRESSION: In comparison with the study of , the monitoring and support devices unchanged. Continued enlargement of the cardiac silhouette with moderate pulmonary vascular congestion the hemidiaphragms are not sharply seen and there is haziness spaces, consistent with bilateral pleural effusions and underlying compressive atelectasis. Although no acute focal pneumonia is appreciated, this would be difficult to exclude in the appropriate clinical setting, especially in the absence of a lateral view. EXAMINATION: CHEST (PORTABLE AP) INDICATION:  year old man with IVH, respiratory failure. Interval change from prior? TECHNIQUE: 2 frontal views of the chest COMPARISON:  FINDINGS: There are bibasilar patchy opacities, slightly increased, more so on the right. Vascular congestion with minimal edema. Mild cardiomegaly stable. No significant pleural effusion or pneumothorax. ET tube 5.9 cm above the carina, proper position. NG tube is at least in the stomach and coursing inferiorly off the film. Right IJ catheter terminates in the proximal SVC as before. IMPRESSION: Interval increased bibasilar opacities which could reflect developing or worsening pneumonia. Mild edema slightly improved. INDICATION:  year old man with massive intraparencymal hemorrhage now pronounced brain dead and currently undergoing organ procurement process per NEOB. Assess for consolidation. Please try for study as close to 0500 as possible, per NEOB and transplant surgeons. TECHNIQUE: MDCT axial images were acquired through the chest and abdomen without intravenous contrast. After intravenous contrast, multi phasic images through the abdomen were obtained with abdomen and pelvis in portal venous phase. Coronal and sagittal reformations were performed and reviewed on PACS. DOSE: Acquisition sequence: 1) Spiral Acquisition 3.6 s, 48.2 cm; CTDIvol  14.0 mGy (Body) DLP  671.9 mGy-cm. 2) Spiral Acquisition 2.5 s, 33.4 cm; CTDIvol  14.0 mGy (Body) DLP  466.3 mGy-cm. 3) Spiral Acquisition 4.3 s, 56.4 cm; CTDIvol  15.4 mGy (Body) DLP  867.6 mGy-cm. 4) Spiral Acquisition 2.6 s, 34.2 cm; CTDIvol  13.9 mGy (Body) DLP  473.9 mGy-cm. 5) Stationary Acquisition 0.6 s, 0.5 cm; CTDIvol  3.3 mGy (Body) DLP  1.7 mGy-cm. 6) Stationary Acquisition 5.4 s, 0.5 cm; CTDIvol  30.1 mGy (Body) DLP  15.0 mGy-cm. Total DLP (Body)  2,496 mGy-cm. COMPARISON: CT chest  FINDINGS: CHEST: HEART AND VASCULATURE: The thoracic aorta is normal in caliber without evidence of acute injury. The heart, pericardium, and great vessels are within normal limits. No pericardial effusion is seen. AXILLA, HILA, AND MEDIASTINUM: No axillary, mediastinal, or hilar lymphadenopathy is present. No mediastinal mass or hematoma. There is fluid within the distal esophagus. Enteric catheter is seen. PLEURAL SPACES: Bilateral pleural effusions are small. LUNGSAIRWAYS: Patient is intubated.  opacities in bilateral lungs, most predominantly in the right upper lobe are suspicious for pneumonia. There is mixed  ...
#
#
# SUBJECT ID 10952108:
# CHEST SINGLE VIEW ON . HISTORY: Respiratory failure. REFERENCE EXAM: . FINDINGS: The endotracheal tube is 3 cm above the carina. This PICC line tip is in the SVC. There are moderate bilateral pleural effusions, right greater than left that have increased compared to the prior study. The heart size continues to be enlarged. The upper lungs are clear. INDICATION: Renal failure, intubated. COMPARISON: CXR . PORTABLE CHEST: The endotracheal tube has been slightly withdrawn, now positioned 3.8 cm above the carina. A right PIC catheter likely terminates within the brachiocephalic vein. Cardiomegaly is stable with atherosclerotic calcifications involving the aortic arch and descending aorta. Bilateral moderate pleural effusions and associated atelectasis are unchanged. There is no pneumothorax. IMPRESSION: 1. Satisfactory positioning of endotracheal tube. 2. Persistent moderate bilateral pleural effusions. HISTORY: Respiratory failure and sepsis. FINDINGS: In comparison with the study of , the tip of the right IJ catheter has been pulled back slightly. Bilateral pleural collections persist as does enlargement of the cardiac silhouette. Monitoring and support devices remain in place. The right subclavian catheter tip again lies outside of the hemithorax. PORTABLE CHEST ON  AT 08:31 INDICATION: MRSA pneumonia - check for change.  at 08:30. FINDINGS: Lines and tubes remain in place and compared to the prior study there is no significant interval change with consistent pleural collections and no new consolidations. REASON FOR EXAMINATION: Followup of the patient, intubated. Portable AP chest radiograph was compared to . The ET tube tip is 6 cm above the carina. The patient is rotated which prevents the precise evaluation of the right PICC line position, but it is most likely within the right subclavian vein. There are bilateral pleural effusion that appears to be slightly increased since the prior study. The position in the contours of the mediastinum cannot be evaluated due to significant rotation of the patient. INDICATION:  woman with right breast pain and lower extremity swelling. For evaluation of infiltrate or edema. . PA AND LATERAL CHEST: Marked cardiomegaly is new since . The aorta is tortuous and calcified. The lungs are clear without evidence of consolidation. Prominent vessels and Kerley B lines likely reflect mild CHF. Stable left pleural effusion or pleural thickening is unchanged since . Multilevel degenerative changes in the thoracolumbar spine and rib deformities are similar to . IMPRESSION: Increase in heart size since , with mild CHF. INDICATION: New nasogastric tube placement. FINDINGS: Comparison is made to , 20:58. Nasogastric tube is in place, extending into the stomach, below the diaphragm and out of view. Cardiomediastinal silhouette is enlarged, unchanged. Bibasilar atelectasis, and layering pleural effusions are not significantly changed, allowing for differences in patient positioning. The overall degree of volume overload has not significantly changed. HISTORY:  female with extensive vaginal bleeding. COMPARISON: None available in the  PACS. PELVIC ULTRASOUND: Transabdominal ultrasound was performed. The uterus measures approximately 7.2 x 3.9 x 5.1 cm, enlarged for the patients age. Within the uterus, there is heterogeneous material representing a combination of vascularized soft tissue as well as possible blood products filling essentially the entire uterus, making delineation of the endometrium not possible by transabdominal technique. As the patient was unable to verbally consent transvaginal ultrasound, given dementia and previous CVAs, the patients daughter  was contacted, and did not wish to pursue transvaginal ultrasound at this time. IMPRESSION: Enlarged uterus with soft tissue and possiblly blood products suggests endometrial neoplasm. Although endometrial evaluation is superior with transvaginal technique, decision was made not to pursue at this time. Findings discussed with Dr.  after scan complet ...
#
#
# SUBJECT ID 17135164:
# CLINICAL INFORMATION:  man with alcoholic cirrhosis and HCC being treated with CyberKnife. He was incidentally noted to have splenic artery aneurysms on prior CT scan. Request is made for splenic arteriogram with possible embolization of the aneurysms. COMPARISON: CT abdomen with contrast from . FELLOW: . RESIDENT: . STAFF RADIOLOGIST: , who supervised procedure. ANESTHESIA: Moderate sedation was provided by administering divided doses of a total of 125 mcg of fentanyl and 6 mg of Versed throughout the total intraservice time of 4 hours 55 minutes during which the patients hemodynamic parameters were continuously monitored. 1 lidocaine was used for local anesthesia. PROCEDURES: 1. Celiac axis arteriogram. 2. Splenic arteriogram. 3. No intervention performed. CONTRAST: Approximately 280 cc of Optiray. PROCEDURE AND FINDINGS: After review of the risks and benefits of the procedure as well as conscious sedation, informed consent was obtained. The patient was brought to the angiography suite and placed supine on the imaging table. The right groin was prepped and draped in the usual sterile fashion. Access was obtained under ultrasound guidance with a micropuncture needle into the common femoral artery. A 0.018 wire was advanced through the needle into the abdominal aorta. The needle was removed and replaced with a micropuncture sheath, which was used to upsized the wire to  wire. The micropuncture sheath was removed and replaced with a 5  vascular sheath, which was attached to a sidearm suction. Initially, a C2 catheter was used to select the celiac axis. An arteriogram was performed, which demonstrated the splenic artery, and the common hepatic artery and its branches. A small aneurysm was seen at the origin of the common hepatic artery, which is better seen on prior CT angiography. Subsequently, the C2 catheter was exchanged for  catheter, which was used to select the celiac trunk. A celiac angiogam was performed with 3D reconstructions which were performed by Dr  on A dedicated 3D workstation. This demonstrated an extremely tortuous, large diameter splenic artery. Two splenic artery aneurysms were seen. The first measures 3.0 x 1.4 cm, and the second more distal aneurysm measures 1.6 x 1.9 cm. A Renegade STS microcatheter and 016 Fathom microwire were placed through the  catheter and advanced across the larger more proximal aneurysm. However, when attempting to exchange for a stiffer wire, access was lost. Numerous catheters and wires were used to attempt to cross the larger more proximal aneurysm with a stiffener wire to enable stenting or coiling. These included a C2 Glide catheter, and angled-tapered Glide catheter, a Glidewire, and a stiff Glidewire. However, these attempts ultimately proved unsuccessful. Access to the neck of the aneurysm was obtained with a 4  angled-tapered Glide catheter and distal to the aneurysm access was obtained with the Renegade STS microcather and V18 control wire. However despite being able to gain access distal the aneurysm with a microwire and catheter we were unable to advance the 4  glide catheter beyond the aneurysm and as a result a wire stiff enough to allow stenting could not be placed. The neck of the aneurysm was a least 2 cm wide and would not allow safe coiling of the aneuysm without significant risk of occluding the splenic artery. AS a result the decision was made to terminate the procedure. The catheters and wires were removed. Through the sidearm of the sheath, contrast was injected to demonstrate that the bifurcation of the common femoral artery was approximately 4 cm below the access site. As such, Angio- Seal device was used for closure. There were no immediate complications. IMPRESSION: 1. Celiac axis arteriogram and splenic arteriogram demonstrating a small aneurysm at the origin of the common hepatic artery, and two splenic artery aneurysms measuring 3.0 x 1.4 cm and 1.6 x 1.9 cm, respectively. 2. Unsuccessful attempts at crossing the larger more proximal aneurysm with a st ...
#
#
# SUBJECT ID 13594409:
# EXAMINATION: UNILAT UP EXT VEINS US RIGHT INDICATION:  year old woman with asymmetric RUE edema.  ? basilic, subclavian DVT? TECHNIQUE: Grey scale and Doppler evaluation was performed on the right upper extremity veins. COMPARISON: None. FINDINGS: There is normal flow with respiratory variation in the right subclavian vein. The catheter seen within the right internal jugular vein. The right internal jugular and axillary veins are patent, show normal color flow and compressibility. The right brachial, basilic, and cephalic veins are patent, compressible and show normal color flow and augmentation. IMPRESSION: No evidence of deep vein thrombosis in the right upper extremity. EXAMINATION: DX CHEST PORT LINETUBE PLCMT 1 EXAM INDICATION:  year old woman sp R IJ CVL placement  eval location Contact name: sicu, :   COMPARISON:  IMPRESSION: A right central venous line tip is in the right atrium. There is no pneumothorax. The patient is substantially rotated.There are low lung volumes. Allowing for changes due to this, the cardiomediastinal silhouettes are stable, reflective of mild cardiac enlargement. Subtle right lung diffuse opacification may relate to overlying soft tissue. No definite focal consolidation. INDICATION:  year old woman with ostomy, on TPN here with fungemia needs picc for TPNantifungals  Please place PICC COMPARISON: Chest radiograph . TECHNIQUE: OPERATORS: Dr. , Interventional Radiology Fellow and Dr. , attending radiologist performed the procedure. Dr.   personally supervised the trainee during the key components of the procedure and has reviewed and agrees with the trainees findings. ANESTHESIA: Bupivacaine was injected in the skin and subcutaneous tissues overlying the access site (patient reports a lidocaine allergy). FLUOROSCOPY TIME AND DOSE: 1.3 min, 17 mGy PROCEDURE: 1. Double lumen PICC placement through the brachial vein on the left. PROCEDURE DETAILS: Using sterile technique and local anesthesia, the brachial vein on the left was punctured under direct ultrasound guidance using a micropuncture set. Permanent ultrasound images were obtained before and after intravenous access, which confirmed vein patency. A peel-away sheath was then placed over a guidewire. The guidewire was then advanced into the superior vena cava using fluoroscopic guidance. A double lumen PIC line measuring 44 cm in length was then placed through the peel-away sheath with its tip positioned in the distal SVC under fluoroscopic guidance. Position of the catheter was confirmed by a fluoroscopic spot film of the chest. The peel-away sheath and guidewire were then removed. The catheter was secured to the skin, flushed, and a sterile dressing applied. The patient tolerated the procedure well. There were no immediate complications. FINDINGS: 1. The accessed vein was patent and compressible. 2. Brachialvein approach double lumen left PICC with tip in the distal SVC. IMPRESSION: Successful placement of a left 44 cm brachial approach double lumen PowerPICC with tip in the distal SVC. The line is ready to use. EXAMINATION: PORTABLE AP CHEST RADIOGRAPHS. INDICATION:  year old woman with peritoneal carcinomatosis, entercutaneous fistula who presents with sepsis. Developed SOB and tachypnea this AM. source of shortness of breath TECHNIQUE: AP chest x-ray COMPARISON: Prior chest radiographs dated . FINDINGS: In comparison to previous chest radiograph dated . A left-sided PICC line is unchanged from previous. There are decreased lung volumes bilaterally. There is increased haziness along the right lower lung, which is likely due to the overlying soft tissue mass. There is no change in visibility of pulmonary vessels on the right which makes pneumonia less likely. No pneumothorax. IMPRESSION: Increased haziness in opacification of the right lower lung which is likely due to an overlying soft tissue mass. A lateral view would be helpful if there is a strong clinical suspicion for pneumonia. INDICATION:  year old woman with worsening resp status ? inc ...
